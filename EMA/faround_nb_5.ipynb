# %%
import psycopg2
import numpy as np
import pandas as pd

# %%
from matplotlib import pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import FuncFormatter

# %%
from datetime import time

# %%
host="192.168.2.23"
port=5432
user="amt"
dbname="qdap_test"

# %%
def make_connection_to_db(host, port, user, dbname):
    conn = psycopg2.connect(host= host, port=port, user=user, dbname=dbname)
    cursor = conn.cursor()
    return cursor, conn

# %%
def fetch_options_data(cursor, symbol, strike_price, date, month, year, type):
    cursor.execute(
        f'''
            SELECT *
            FROM ohlcv_options_per_minute oopm
            WHERE symbol = '{option}' 
            AND strike = {strike_price} 
            AND extract(year from oopm.expiry) = {year} 
            AND extract(month from oopm.expiry) = {month}
            AND extract(day from oopm.expiry) = {date}
            AND opt_type = '{type}'
            ORDER BY date_timestamp ASC;
        '''
    )
    rows = cursor.fetchall()
    df = pd.DataFrame(rows, columns=[desc[0] for desc in cursor.description])
    return df

def fetch_options_data(cursor, symbol, expiry):
    cursor.execute(
        f'''
            SELECT *
            FROM ohlcv_options_per_minute oopm
            WHERE symbol = '{symbol}' 
            AND expiry_type = 'I'
            AND expiry = (
                SELECT MAX(oopmm.expiry)
                FROM ohlcv_options_per_minute oopmm
                WHERE oopmm.symbol = '{symbol}'
                AND oopmm.expiry_type = 'I'
                AND oopmm.expiry <= '{expiry}'
            )
            ORDER BY date_timestamp ASC;
            
        '''
    )
    rows = cursor.fetchall()
    df = pd.DataFrame(rows, columns=[desc[0] for desc in cursor.description])
    return df

# %%
def fetch_futures_data(cursor, symbol, x=0):
    query = f'''
        SELECT *
        FROM ohlcv_future_per_minute ofpm
        WHERE ofpm.symbol = '{symbol}'
        AND ofpm.expiry_type = 'I'
        AND ofpm.expiry = (
            SELECT ofpmm.expiry 
            FROM ohlcv_future_per_minute ofpmm
            WHERE ofpmm.symbol = '{symbol}'
            AND ofpmm.expiry_type = 'I'
            GROUP BY ofpmm.expiry
            OFFSET {x}
            LIMIT 1
        )
        ORDER BY date_timestamp ASC;
    '''
    cursor.execute(query)
    rows = cursor.fetchall()
    df = pd.DataFrame(rows, columns=[desc[0] for desc in cursor.description])
    return df

# %%
def fetch_equity_data(cursor, symbol, begin, expiry):
    query = f'''
        SELECT *
        FROM ohlcv_cm_per_minute ocpm
        WHERE ocpm.symbol = '{symbol}'
        AND date_timestamp <= '{expiry}'
        AND date_timestamp >= '{begin}'
        ORDER BY date_timestamp ASC;
    '''
    cursor.execute(query)
    rows = cursor.fetchall()
    df = pd.DataFrame(rows, columns=[desc[0] for desc in cursor.description])
    return df

# %%
def fetch(host, port, user, dbname, symbol, x=15):
    cursor, conn = make_connection_to_db(host, port, user, dbname)
    # hardcoded for near month expiry
    df_futures = fetch_futures_data(cursor, symbol, x) # date is the expiry
    expiry = df_futures['expiry'].iloc[0]
    df_options = fetch_options_data(cursor, symbol, expiry)
    cursor.close()
    conn.close()
    return df_futures, df_options

# %%
symbol = "BANKNIFTY"
x = 20 # index of the array of all the unique expiries of I futures. 
moneyness_strike = 0
fund_locked = 1000 # inr
transaction_cost = 11.5
slippage = 10

# %%
fund_locked *= 100

# %%
DF_FUTURES, DF_OPTIONS = fetch(host, port, user, dbname, symbol, x)

# %%
# ====================================================================================================================================== #

# %%
df_futures = DF_FUTURES.copy()
df_options = DF_OPTIONS.copy()

# %%
df_futures = df_futures.drop_duplicates(subset='date_timestamp', keep='first')
df_options = df_options.drop_duplicates(subset=['date_timestamp', 'strike', 'opt_type'], keep='first')

# %%
df_calls = df_options[(df_options['opt_type'] == 'CE')]
df_puts  = df_options[(df_options['opt_type'] == 'PE')]

# %%
df_futures.set_index('date_timestamp', inplace=True)
df_calls.set_index('date_timestamp', inplace=True)
df_puts.set_index('date_timestamp', inplace=True)

# %%
# NOTE THAT OPTIONS AND FUTURES EXPIRY IN THE QDAP DATABASE ARE NOT FOLLOWING THE SAME FORMAT.
expiry_options = pd.Timestamp(df_options['expiry'].iloc[0]).date()
expiry_futures = pd.Timestamp(df_futures['expiry'].iloc[0]).date()
starts_options = pd.Timestamp(timestamps[0]).date()
starts_futures = pd.Timestamp(df_futures.index[0]).date()

start_intersection = max(starts_options, starts_futures)
end_intersection = min(expiry_options, expiry_futures)
start_intersection = pd.Timestamp.combine(start_intersection, pd.Timestamp('09:15:00').time())
end_intersection = pd.Timestamp.combine(end_intersection, pd.Timestamp('15:29:00').time())

print("starts_options:", starts_options)
print("expiry_options:", expiry_options)
print("starts_futures:", starts_futures)
print("expiry_futures:", expiry_futures)
print("start_intersection:", start_intersection)
print("end_intersection:", end_intersection)

range_futures = (df_futures.index <= end_intersection) & (df_futures.index >= start_intersection)
range_options = (df_options['date_timestamp'] <= end_intersection) & (df_options['date_timestamp'] >= start_intersection)

df_futures = df_futures[range_futures]
df_options = df_options[range_options]
# df_futures = df_futures[range_futures]
# df_options = df_options[range_options]
# Out:
# starts_options: 2023-12-01
# expiry_options: 2023-12-28
# starts_futures: 2023-12-01
# expiry_futures: 2023-12-28
# start_intersection: 2023-12-01 09:15:00
# end_intersection: 2023-12-28 15:29:00

# %%
df_calls_close = df_calls.pivot(columns='strike', values='close').ffill()
df_puts_close = df_puts.pivot(columns='strike', values='close').ffill()

# %%
df_calls_open = df_calls.pivot(columns='strike', values='open').ffill()
df_puts_open = df_puts.pivot(columns='strike', values='open').ffill()

# %%
market_holidays = [
    (1, 26), (3, 8), (3, 29), (4, 19), (5, 1),
    (8, 15), (10, 2), (10, 24), (11, 12), (12, 25)
]

trading_days = pd.date_range(start=start_intersection, end=end_intersection, freq='B')
trading_days = trading_days[~trading_days.to_series().apply(lambda x: (x.month, x.day) in market_holidays)]

# Generate a complete range of trading minutes for each trading day
trading_minutes = pd.date_range(start='09:15:00', end='15:29:00', freq='min').time

# Create a complete index of trading timestamps
complete_index = pd.DatetimeIndex([pd.Timestamp.combine(day, time) for day in trading_days for time in trading_minutes])

# %%
df_futures = df_futures.reindex(complete_index).ffill()
df_calls_close = df_calls_close.reindex(complete_index).ffill()
df_puts_close = df_puts_close.reindex(complete_index).ffill()
df_calls_open = df_calls_open.reindex(complete_index).ffill()
df_puts_open = df_puts_open.reindex(complete_index).ffill()

# %%
timestamps = df_futures.index.unique()
timestamps = pd.Series(timestamps)
timestamps
# Out:
# DatetimeIndex(['2023-12-01 09:15:00', '2023-12-01 09:16:00',
#                '2023-12-01 09:17:00', '2023-12-01 09:18:00',
#                '2023-12-01 09:19:00', '2023-12-01 09:20:00',
#                '2023-12-01 09:21:00', '2023-12-01 09:22:00',
#                '2023-12-01 09:23:00', '2023-12-01 09:24:00',
#                ...
#                '2023-12-28 15:20:00', '2023-12-28 15:21:00',
#                '2023-12-28 15:22:00', '2023-12-28 15:23:00',
#                '2023-12-28 15:24:00', '2023-12-28 15:25:00',
#                '2023-12-28 15:26:00', '2023-12-28 15:27:00',
#                '2023-12-28 15:28:00', '2023-12-28 15:29:00'],
#               dtype='datetime64[ns]', length=7125, freq=None)

# %%
df_call_put_open = [df_puts_open, df_calls_open]
df_call_put_close = [df_puts_close, df_calls_close]

# %%
put_strikes = np.array(df_puts_close.columns, dtype=int)
call_strikes = np.array(df_calls_close.columns, dtype=int)

# %%
strikes = [put_strikes, call_strikes]

# %%
print(df_calls_close.shape, df_calls_open.shape)
print(df_puts_close.shape, df_puts_open.shape)
print(df_futures.shape)
# Out:
# (7125, 119) (7125, 119)
# (7125, 127) (7125, 127)
# (7125, 9)

# %%
def ema(window_short, window_long, df):
    df['short'] = df['close'].ewm(span=window_short).mean()
    df['long'] = df['close'].ewm(span=window_long).mean() 
    polarity = df['short'] - df['long']
    polarity = polarity > 0
    signals = []
    position_polarity_positive = polarity.iloc[window_long]
    for i in range(window_long, df.shape[0]):
        if(polarity.iloc[i] != position_polarity_positive):
            position_polarity_positive = polarity.iloc[i]
            signals.append((int(position_polarity_positive), df.index[i], df.index[i+1]))
            # bullish -> (1, signal_time, valid_trade_time), bearish -> (0, signal_time, valid_trade_time)
    df_signals = pd.DataFrame(signals, columns=['Signal Type', "Signal Time", "Valid Tradable Time"])
    df_signals.set_index('Signal Time', inplace=True)
    return signals, df_signals

# %%
# bullish -> (1, signal_time, valid_trade_time), bearish -> (0, signal_time, valid_trade_time)
window_short = 9
window_long = 26
signals, df_signals = ema(window_short, window_long, df_futures)
print(len(signals))
df_signals
# Out:
# 282
#                      Signal Type Valid Tradable Time
# Signal Time
# 2023-12-01 10:37:00            0 2023-12-01 10:38:00
# 2023-12-01 10:39:00            1 2023-12-01 10:40:00
# 2023-12-01 10:42:00            0 2023-12-01 10:43:00
# 2023-12-01 11:04:00            1 2023-12-01 11:05:00
# 2023-12-01 11:50:00            0 2023-12-01 11:51:00
# ...                          ...                 ...
# 2023-12-28 13:25:00            1 2023-12-28 13:26:00
# 2023-12-28 13:26:00            0 2023-12-28 13:27:00
# 2023-12-28 14:03:00            1 2023-12-28 14:04:00
# 2023-12-28 14:14:00            0 2023-12-28 14:15:00
# 2023-12-28 14:57:00            1 2023-12-28 14:58:00
#
# [282 rows x 2 columns]

# %%
df_futures
# Out:
#                         symbol     open      low     high    close  volume  \
# 2023-12-01 09:15:00  BANKNIFTY  4479145  4476270  4483685  4482335   48975
# 2023-12-01 09:16:00  BANKNIFTY  4482165  4478740  4482625  4482285   29175
# 2023-12-01 09:17:00  BANKNIFTY  4482795  4481350  4483715  4483200   27660
# 2023-12-01 09:18:00  BANKNIFTY  4483240  4483240  4486500  4486500   23925
# 2023-12-01 09:19:00  BANKNIFTY  4486430  4485600  4487500  4486620   15240
# ...                        ...      ...      ...      ...      ...     ...
# 2023-12-28 15:25:00  BANKNIFTY  4850775  4850370  4851095  4850655    8535
# 2023-12-28 15:26:00  BANKNIFTY  4850655  4850530  4851405  4851100    5400
# 2023-12-28 15:27:00  BANKNIFTY  4851100  4850700  4851300  4851015    2130
# 2023-12-28 15:28:00  BANKNIFTY  4851005  4851005  4851645  4851625    8220
# 2023-12-28 15:29:00  BANKNIFTY  4851625  4850400  4851645  4851500    8085
#
#                                  expiry expiry_type        id         short  \
# 2023-12-01 09:15:00 2023-12-28 14:30:00           I  13448954  4.482335e+06
# 2023-12-01 09:16:00 2023-12-28 14:30:00           I  60243858  4.482307e+06
# 2023-12-01 09:17:00 2023-12-28 14:30:00           I  13448956  4.482673e+06
# 2023-12-01 09:18:00 2023-12-28 14:30:00           I  60243860  4.483969e+06
# 2023-12-01 09:19:00 2023-12-28 14:30:00           I  13448958  4.484758e+06
# ...                                 ...         ...       ...           ...
# 2023-12-28 15:25:00 2023-12-28 14:30:00           I  62096267  4.850869e+06
# 2023-12-28 15:26:00 2023-12-28 14:30:00           I  15301365  4.850915e+06
# 2023-12-28 15:27:00 2023-12-28 14:30:00           I  62096269  4.850935e+06
# 2023-12-28 15:28:00 2023-12-28 14:30:00           I  15301367  4.851073e+06
# 2023-12-28 15:29:00 2023-12-28 14:30:00           I  62096271  4.851158e+06
#
#                              long
# 2023-12-01 09:15:00  4.482335e+06
# 2023-12-01 09:16:00  4.482309e+06
# 2023-12-01 09:17:00  4.482629e+06
# 2023-12-01 09:18:00  4.483711e+06
# 2023-12-01 09:19:00  4.484386e+06
# ...                           ...
# 2023-12-28 15:25:00  4.850641e+06
# 2023-12-28 15:26:00  4.850675e+06
# 2023-12-28 15:27:00  4.850700e+06
# 2023-12-28 15:28:00  4.850769e+06
# 2023-12-28 15:29:00  4.850823e+06
#
# [7125 rows x 11 columns]

# %%
def find_closest_strike(strikes, value):
    strikes = np.array(strikes)
    strikes.sort()
    closest_strike_index = np.argmin(np.abs(strikes - int(value)))
    closest_strike = strikes[closest_strike_index]
    return closest_strike, closest_strike_index

# %%
def choose_strike_of_moneyness(opt_type, index_strike, futures_price, strikes):
    # decision logic
    call_put = (1)*(opt_type) + (-1)*(1-opt_type)
    moneyness = (1)*(index_strike >= 0) + (-1)*(index_strike < 0)
    decision = call_put * moneyness
    # ITM calls (+1 * +1) and OTM puts (-1 * -1) will have a strike < futures_price
    # OTM calls (-1 * +1) and ITM puts (+1 * -1) will have a strike > futures_price
    num_strikes = len(strikes)
    closest_strike, index = find_closest_strike(strikes, futures_price)
    if decision == 1:
        if index >= index_strike:
            strike = strikes[index-index_strike]
        else:
            eligible_candidates = strikes[:index]
            strike = -1
    else:
        if index + index_strike < num_strikes:
            strike = strikes[index+index_strike]
        else:
            eligible_candidates = strikes[index:]
            strike = -1
    if strike == -1:
        moneyness = "ATM" if index_strike == 0 else ["OTM", "ITM"][index_strike >= 0]
        print(f"{["BEARISH", "BULLISH"][opt_type]} SIGNAL WASTED: Couln't find an {moneyness}-{abs(index_strike)} {["PUT", "CALL"][opt_type]} option trade in the database at {df_target.index[0]}.")
        print(f">>> Futures price: {futures_price}.")
        print(f">>> Eligible strikes traded on/or before the current timestamp: {[i for i in eligible_candidates]}")
        print()
    return strike

# %%
# format of trades
# (number, 1/0, 1/0, t, s)
# (price, call/put, long/short, timestamp, strike)
# format of trades
# (number, 1/0, 1/0, t, s)
# (price, call/put, long/short, timestamp, strike)

# trades happening on open
def make_trades(signals, moneyness_strike, expiry, df_futures, df_calls_puts_open, fund_locked, strikes):
    available_funds = fund_locked
    trades = []
    ix = 0
    # brute forcing the first trade (fund locking)
    while ix < len(signals):
        # first signal details
        first_signal_type = signals[ix][0]
        first_valid_tradable_timestamp = signals[ix][2]
        futures_price = df_futures['open'].loc[first_valid_tradable_timestamp]

        # calculation and logic
        # opt_type = ["PE", "CE"][first_signal_type]
        # df_target = df_calls_puts_open[first_signal_type].loc[first_valid_tradable_timestamp]
        strike = choose_strike_of_moneyness(first_signal_type, moneyness_strike, futures_price, strikes[first_signal_type])
        if strike == -1:
            ix += 1
            continue
        price = df_calls_puts_open[first_signal_type][strike].loc[first_valid_tradable_timestamp]
        
        # validity of positions (fund locking)
        if price <= available_funds:
            trades.append((price, first_signal_type, 1, first_valid_tradable_timestamp, strike))
            available_funds -= price
            break
        ix += 1

    # executing trades as per the signals generated
    for i, signal in enumerate(signals[ix + 1:]):
        # last trade details
        last_trade = trades[len(trades) - 1]
        last_trade_price = last_trade[0]
        last_trade_opt_type = last_trade[1]
        last_trade_position = last_trade[2]
        last_strike = last_trade[4]

        # current signal details
        signal_nature = signal[0]
        signal_time_stamp = signal[1]
        valid_tradable_time_stamp = signal[2]

        # calculation and logic
        square_off_price = df_calls_puts_open[last_trade_opt_type][last_strike].loc[valid_tradable_time_stamp]
        futures_price = df_futures['open'].loc[valid_tradable_time_stamp]
        # opt_type = ["PE", "CE"][signal_nature]  # df of calls/puts (rows-> timestamps, cols-> strikes, values-> close)
        # df_target = df_calls_puts_open[signal_nature].loc[valid_tradable_time_stamp]
        current_strike = choose_strike_of_moneyness(signal_nature, moneyness_strike, futures_price, strikes[signal_nature])
        if current_strike == -1:
            continue
        buying_price = df_calls_puts_open[signal_nature][current_strike].loc[valid_tradable_time_stamp]

        # validity of positions (fund locking)
        if last_trade_position == 1:
            trades.append((square_off_price, last_trade_opt_type, 0, valid_tradable_time_stamp, last_strike))
            available_funds += square_off_price
            available_funds = min(available_funds, fund_locked)
            # print(f"Sold {["Put", "Call"][last_trade_opt_type]} of strike {last_strike} at {valid_tradable_time_stamp} worth rs {square_off_price/100}. funds remaining after squaring off last position (no net active position right now) = {available_funds/100}")
        if buying_price <= available_funds:
            trades.append((buying_price, signal_nature, 1, valid_tradable_time_stamp, current_strike))
            available_funds -= buying_price
            # print(f"Bought {["Put", "Call"][signal_nature]} of strike {current_strike} at {valid_tradable_time_stamp} worth rs {buying_price/100}. funds remaining after squaring off last position (no net active position right now) = {available_funds/100}")
        # else:
        #     print(f"XXXX COULD NOT XXXX buy {["Put", "Call"][signal_nature]} of strike {current_strike} at {valid_tradable_time_stamp} worth rs {buying_price/100}. funds remaining after squaring off last position (no net active position right now) = {available_funds/100}")

    # manually squaring off the last trade at the last tradable minute
    last_trade = trades[len(trades) - 1]
    last_trade_opt_type = last_trade[1]
    last_trade_strike = last_trade[4]
    expiry = pd.to_datetime(expiry, format='%d-%m-%Y')
    last_valid_tradable_time_stamp = pd.Timestamp(f"{expiry} 15:29:00")
    last_square_off_price = df_calls_puts_open[last_trade_opt_type][last_trade_strike].loc[last_valid_tradable_time_stamp]
    if last_trade_position == 1:
        trades.append((last_square_off_price, last_trade_opt_type, 0, last_valid_tradable_time_stamp, last_trade_strike))
    # trades.append((last_square_off_price, last_trade_opt_type, 0, last_valid_tradable_time_stamp, last_trade_strike))
    df_trades = pd.DataFrame(trades, columns=['Price', 'Call/Put', 'Position', 'date_timestamp', 'strike_price'])
    df_trades = df_trades.set_index('date_timestamp')
    return trades, df_trades

# %%
def stats_per_trade(open, close, timestamps, df_call_put_open, fund_blocked, risk_free=12):
    opt_type = open['Call/Put']
    strike = open['strike_price']

    open_time = open.name
    close_time = close.name
    # time_stamps = df_options.loc[open_time:close_time].index
    holding_period = (close_time - open_time).total_seconds() / 60

    open_price = open['Price']
    close_price = close['Price']
    profit = close_price - open_price - get_expense_cost(11.5, 10, close_price) - get_expense_cost(11.5, 10, open_price)
    # profit = close_price - open_price
    
    dd = 0
    max_dd = 0
    last_max_price = close_price
    opens = df_call_put_open[int(opt_type)][int(strike)]
    variations = []
    for timestamp in timestamps.loc[(timestamps <= close_time) & (timestamps >= open_time)]:
        last_max_price = max(last_max_price, opens[timestamp])
        dd = min(dd, opens.loc[timestamp] - last_max_price)
        max_dd = min(dd, max_dd)
        variations.append(opens.loc[timestamp])

    variations = np.array(variations)
    print("granularity/ variations in profits or open_prices during the holding period:")
    print(variations)
    std_granularity = variations.std()
    if std_granularity == 0:
        std_granularity = 1
    sharpe = profit - risk_free * 1 / 365 * 1 / 24 * 1 / 60 * 1 / 100 * open_price * holding_period
    sharpe /= std_granularity
    return max_dd, profit, holding_period, std_granularity, sharpe

# %%
def print_trades(df_trades, timestamps, df_call_put_open, fund_blocked):
    open_position = None
    open_details = []
    close_details = []
    sharpes = []
    for i, row in df_trades.iterrows():
        pos = "Sell"
        open_position = False
        close_details = row
        if row["Position"]:
            pos = "Buy "
            open_position = True
            open_details = row
        type = "Put"
        if row["Call/Put"]:
            type = "Call"
        strike = row["strike_price"]
        price = row["Price"]
        print(f"at time: {i} || {pos} {type} option of strike = {strike} for a price of {price}")
        if not open_position:
            print("==> TRADE STATS")
            max_dd, profit, holding_period, std, sharpe = stats_per_trade(open_details, close_details, timestamps, df_call_put_open, fund_blocked)
            sharpes.append(sharpe)
            print(">>>> maximum drawdown:", max_dd)
            print(">>>> profit (expense adjusted):", profit)
            print(">>>> holding period:", holding_period, "minutes")
            print(">>>> standard deviation:", std)
            print(">>>> sharpe:", sharpe)
            print("=========================================================================================================")
    sharpes = pd.Series(sharpes)
    print(sharpes.mean())

# %%
trades, df_trades = make_trades(signals, moneyness_strike, end_intersection, df_futures, df_call_put_open, fund_locked, strikes)

# %%
df_trades.to_csv("trades_vinayak_new.csv")

# %%
df_trades
# Out:
#                        Price  Call/Put  Position  strike_price
# date_timestamp
# 2023-12-01 10:38:00  58740.0         0         1       4510000
# 2023-12-01 10:40:00  58180.0         0         0       4510000
# 2023-12-01 10:40:00  62790.0         1         1       4510000
# 2023-12-01 10:43:00  61080.0         1         0       4510000
# 2023-12-01 10:43:00  59150.0         0         1       4510000
# ...                      ...       ...       ...           ...
# 2023-12-28 14:15:00   1940.0         1         0       4860000
# 2023-12-28 14:15:00   5630.0         0         1       4850000
# 2023-12-28 14:58:00   1745.0         0         0       4850000
# 2023-12-28 14:58:00   3910.0         1         1       4850000
# 2023-12-28 15:29:00    960.0         1         0       4850000
#
# [360 rows x 4 columns]

# %%
print_trades(df_trades, timestamps, df_call_put_open, fund_locked)
# Out:
# at time: 2023-12-01 10:38:00 || Buy  Put option of strike = 4510000.0 for a price of 58740.0
# at time: 2023-12-01 10:40:00 || Sell Put option of strike = 4510000.0 for a price of 58180.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [58740. 58155. 58180.]
# >>>> maximum drawdown: -585.0
# >>>> profit (expense adjusted): -811.3779999999999
# >>>> holding period: 2.0 minutes
# >>>> standard deviation: 270.07200685907617
# >>>> sharpe: -3.004401794004515
# =========================================================================================================
# at time: 2023-12-01 10:40:00 || Buy  Call option of strike = 4510000.0 for a price of 62790.0
# at time: 2023-12-01 10:43:00 || Sell Call option of strike = 4510000.0 for a price of 61080.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [62790. 63160. 62090. 61080.]
# >>>> maximum drawdown: -2080.0
# >>>> profit (expense adjusted): -1976.3205
# >>>> holding period: 3.0 minutes
# >>>> standard deviation: 792.2436493907667
# >>>> sharpe: -2.494641021570995
# =========================================================================================================
# at time: 2023-12-01 10:43:00 || Buy  Put option of strike = 4510000.0 for a price of 59150.0
# at time: 2023-12-01 11:05:00 || Sell Put option of strike = 4510000.0 for a price of 58665.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [59150. 58920. 59660. 59490. 59535. 58925. 58925. 58725. 59145. 59300.
#  59300. 59160. 59315. 59500. 59960. 59740. 59700. 59540. 58860. 58860.
#  58860. 58875. 58665.]
# >>>> maximum drawdown: -1295.0
# >>>> profit (expense adjusted): -738.3022500000001
# >>>> holding period: 22.0 minutes
# >>>> standard deviation: 358.48056792571094
# >>>> sharpe: -2.0603609136484167
# =========================================================================================================
# at time: 2023-12-01 11:05:00 || Buy  Call option of strike = 4510000.0 for a price of 62510.0
# at time: 2023-12-01 11:51:00 || Sell Call option of strike = 4510000.0 for a price of 64000.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [62510. 63925. 62915. 62675. 62490. 61955. 62265. 62480. 62160. 62730.
#  63000. 63335. 63335. 62735. 63075. 62985. 62890. 62745. 62220. 62320.
#  62490. 63005. 64565. 65695. 64815. 65470. 63825. 63555. 63250. 63410.
#  63540. 63540. 62920. 62920. 63800. 64055. 64610. 64005. 64320. 64320.
#  64325. 63890. 63315. 63600. 63810. 63370. 64000.]
# >>>> maximum drawdown: -2775.0
# >>>> profit (expense adjusted): 1218.0035
# >>>> holding period: 46.0 minutes
# >>>> standard deviation: 842.9980155030887
# >>>> sharpe: 1.444068645353347
# =========================================================================================================
# at time: 2023-12-01 11:51:00 || Buy  Put option of strike = 4510000.0 for a price of 57905.0
# at time: 2023-12-01 12:01:00 || Sell Put option of strike = 4510000.0 for a price of 58345.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [57905. 58135. 58390. 58080. 58080. 58080. 58080. 58105. 58105. 58310.
#  58345.]
# >>>> maximum drawdown: -440.0
# >>>> profit (expense adjusted): 190.0625
# >>>> holding period: 10.0 minutes
# >>>> standard deviation: 136.51960777040463
# >>>> sharpe: 1.3912309001288161
# =========================================================================================================
# at time: 2023-12-01 12:01:00 || Buy  Call option of strike = 4520000.0 for a price of 59200.0
# at time: 2023-12-01 12:03:00 || Sell Call option of strike = 4520000.0 for a price of 58400.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [59200. 59200. 58400.]
# >>>> maximum drawdown: -800.0
# >>>> profit (expense adjusted): -1052.84
# >>>> holding period: 2.0 minutes
# >>>> standard deviation: 377.12361663282536
# >>>> sharpe: -2.791835317459212
# =========================================================================================================
# at time: 2023-12-01 12:03:00 || Buy  Put option of strike = 4510000.0 for a price of 58490.0
# at time: 2023-12-01 12:39:00 || Sell Put option of strike = 4510000.0 for a price of 58100.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [58490. 58560. 58215. 58230. 58230. 58230. 58460. 58500. 58345. 58520.
#  58600. 59425. 60765. 58800. 59760. 59375. 59865. 59400. 60000. 59380.
#  59690. 60040. 60115. 60115. 59525. 59525. 59525. 59525. 59985. 60050.
#  60050. 59015. 59075. 58700. 58925. 58160. 58100.]
# >>>> maximum drawdown: -2665.0
# >>>> profit (expense adjusted): -640.6685
# >>>> holding period: 36.0 minutes
# >>>> standard deviation: 720.224987167377
# >>>> sharpe: -0.8902068813908386
# =========================================================================================================
# at time: 2023-12-01 12:39:00 || Buy  Call option of strike = 4510000.0 for a price of 61880.0
# at time: 2023-12-01 12:51:00 || Sell Call option of strike = 4510000.0 for a price of 61435.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [61880. 62295. 61900. 61660. 61360. 61360. 60840. 60840. 61380. 61125.
#  61125. 61435. 61435.]
# >>>> maximum drawdown: -1455.0
# >>>> profit (expense adjusted): -710.12725
# >>>> holding period: 12.0 minutes
# >>>> standard deviation: 403.72965352583986
# >>>> sharpe: -1.7593376608416857
# =========================================================================================================
# at time: 2023-12-01 12:51:00 || Buy  Put option of strike = 4510000.0 for a price of 59685.0
# at time: 2023-12-01 13:18:00 || Sell Put option of strike = 4510000.0 for a price of 59200.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [59685. 59685. 59415. 59415. 58980. 58980. 59000. 59835. 59900. 59630.
#  59630. 60695. 60635. 60200. 61000. 60215. 60000. 60000. 60345. 60305.
#  60500. 60000. 60000. 60000. 59420. 59525. 59030. 59200.]
# >>>> maximum drawdown: -1970.0
# >>>> profit (expense adjusted): -740.60275
# >>>> holding period: 27.0 minutes
# >>>> standard deviation: 535.7860368616547
# >>>> sharpe: -1.3829600255599845
# =========================================================================================================
# at time: 2023-12-01 13:18:00 || Buy  Call option of strike = 4510000.0 for a price of 61090.0
# at time: 2023-12-01 14:08:00 || Sell Call option of strike = 4510000.0 for a price of 57840.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [61090. 60550. 60550. 60550. 60830. 60945. 62245. 62200. 61935. 61900.
#  61715. 61715. 61940. 62000. 61785. 61785. 61785. 61835. 62480. 62750.
#  63200. 63000. 62825. 64200. 64365. 63400. 63400. 63400. 63400. 62815.
#  63000. 63055. 63200. 63200. 63225. 63415. 63240. 63850. 63645. 63460.
#  62980. 62980. 63395. 63395. 63545. 63850. 64475. 64290. 64405. 60155.
#  57840.]
# >>>> maximum drawdown: -6635.0
# >>>> profit (expense adjusted): -3505.6995
# >>>> holding period: 50.0 minutes
# >>>> standard deviation: 1283.2790997992392
# >>>> sharpe: -2.7323727745412336
# =========================================================================================================
# at time: 2023-12-01 14:08:00 || Buy  Put option of strike = 4510000.0 for a price of 60905.0
# at time: 2023-12-01 14:25:00 || Sell Put option of strike = 4510000.0 for a price of 57840.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [60905. 59255. 58615. 59500. 59500. 59270. 59395. 59420. 59290. 58680.
#  58860. 58755. 58290. 58580. 58035. 58035. 58035. 57840.]
# >>>> maximum drawdown: -3065.0
# >>>> profit (expense adjusted): -3320.30175
# >>>> holding period: 17.0 minutes
# >>>> standard deviation: 732.7763035955182
# >>>> sharpe: -4.531448578476816
# =========================================================================================================
# at time: 2023-12-01 14:25:00 || Buy  Call option of strike = 4510000.0 for a price of 62250.0
# at time: 2023-12-01 14:27:00 || Sell Call option of strike = 4510000.0 for a price of 61030.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [62250. 61900. 61030.]
# >>>> maximum drawdown: -1220.0
# >>>> profit (expense adjusted): -1485.0520000000001
# [62625. 62270. 63310. 65275. 66755. 66175. 65360. 65050. 62745. 61195.
#  61740. 62575. 62595. 62000. 62610. 63565. 63955. 63720. 64250. 65725.
#  65790. 64710. 63675. 64730. 65575. 63615. 63300. 64000. 63550. 63180.
#  62930. 62570. 62000.]
# >>>> maximum drawdown: -5560.0
# >>>> profit (expense adjusted): -892.9437499999999
# >>>> holding period: 32.0 minutes
# >>>> standard deviation: 1383.8234552759614
# >>>> sharpe: -0.6456035131073954
# =========================================================================================================
# at time: 2023-12-05 14:32:00 || Buy  Call option of strike = 4710000.0 for a price of 66990.0
# at time: 2023-12-05 14:56:00 || Sell Call option of strike = 4710000.0 for a price of 64000.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [66990. 67150. 67675. 67075. 68320. 66305. 66910. 67315. 67000. 66700.
#  66900. 67090. 67000. 64405. 66075. 65655. 65400. 65920. 66490. 66050.
#  66565. 66575. 65710. 65875. 64000.]
# >>>> maximum drawdown: -4320.0
# >>>> profit (expense adjusted): -3271.6285
# >>>> holding period: 24.0 minutes
# >>>> standard deviation: 934.6453872993757
# >>>> sharpe: -3.5007882272307196
# =========================================================================================================
# at time: 2023-12-05 14:56:00 || Buy  Put option of strike = 4710000.0 for a price of 64220.0
# at time: 2023-12-05 15:06:00 || Sell Put option of strike = 4710000.0 for a price of 60400.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [64220. 62345. 62470. 63040. 63360. 63430. 63790. 63235. 61450. 61095.
#  60400.]
# >>>> maximum drawdown: -3820.0
# >>>> profit (expense adjusted): -4087.933
# >>>> holding period: 10.0 minutes
# >>>> standard deviation: 1144.4829934577663
# >>>> sharpe: -3.571988089271179
# =========================================================================================================
# at time: 2023-12-05 15:06:00 || Buy  Call option of strike = 4720000.0 for a price of 62290.0
# at time: 2023-12-05 15:20:00 || Sell Call option of strike = 4720000.0 for a price of 61650.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [62290. 64790. 64015. 63930. 62985. 63335. 61600. 61885. 61395. 61990.
#  62395. 61835. 61305. 62190. 61650.]
# >>>> maximum drawdown: -3485.0
# >>>> profit (expense adjusted): -906.471
# >>>> holding period: 14.0 minutes
# >>>> standard deviation: 1030.5163754157427
# >>>> sharpe: -0.8798211480053791
# =========================================================================================================
# at time: 2023-12-05 15:20:00 || Buy  Put option of strike = 4710000.0 for a price of 61600.0
# at time: 2023-12-06 09:16:00 || Sell Put option of strike = 4710000.0 for a price of 52330.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [61600. 61270. 61795. 62080. 62120. 61650. 61950. 62000. 62120. 61895.
#  56795. 52330.]
# >>>> maximum drawdown: -9790.0
# >>>> profit (expense adjusted): -9514.9495
# >>>> holding period: 1076.0 minutes
# >>>> standard deviation: 2873.838986588033
# >>>> sharpe: -3.3161503932072147
# =========================================================================================================
# at time: 2023-12-06 09:16:00 || Buy  Call option of strike = 4730000.0 for a price of 64995.0
# at time: 2023-12-06 11:47:00 || Sell Call option of strike = 4700000.0 for a price of 62260.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [62900. 63605. 63375. 62680. 62500. 63560. 63270. 63180. 63315. 63460.
#  62570. 62200. 62385. 62345. 62655. 62455. 61735. 62135. 62365. 62470.
#  62300. 62260.]
# >>>> maximum drawdown: -1870.0
# >>>> profit (expense adjusted): -909.094
# >>>> holding period: 21.0 minutes
# >>>> standard deviation: 518.9366511761183
# >>>> sharpe: -1.7524211737240205
# =========================================================================================================
# at time: 2023-12-06 11:47:00 || Buy  Put option of strike = 4700000.0 for a price of 62990.0
# at time: 2023-12-06 12:01:00 || Sell Put option of strike = 4700000.0 for a price of 61700.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [62990. 63390. 63400. 62620. 63165. 63110. 63285. 62920. 63000. 62480.
#  63160. 62675. 62400. 61755. 61700.]
# >>>> maximum drawdown: -1700.0
# >>>> profit (expense adjusted): -1558.0835
# >>>> holding period: 14.0 minutes
# >>>> standard deviation: 516.7225776199664
# >>>> sharpe: -3.015708825956535
# =========================================================================================================
# at time: 2023-12-06 12:01:00 || Buy  Call option of strike = 4700000.0 for a price of 61730.0
# at time: 2023-12-06 12:26:00 || Sell Call option of strike = 4700000.0 for a price of 61105.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [61730. 61510. 61705. 61710. 62050. 62300. 63010. 62850. 62875. 62245.
#  61600. 61535. 61985. 62610. 62825. 63175. 62980. 62870. 62900. 62200.
#  61730. 61880. 60855. 61830. 61105. 61105.]
# >>>> maximum drawdown: -2320.0
# >>>> profit (expense adjusted): -889.0952500000001
# >>>> holding period: 25.0 minutes
# >>>> standard deviation: 655.2965813030429
# >>>> sharpe: -1.357320662979809
# =========================================================================================================
# at time: 2023-12-06 12:26:00 || Buy  Put option of strike = 4700000.0 for a price of 61425.0
# at time: 2023-12-06 13:35:00 || Sell Put option of strike = 4700000.0 for a price of 64645.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [61425. 62915. 63900. 64035. 63450. 63115. 63710. 64405. 64505. 64900.
#  64450. 63500. 62540. 62555. 62280. 62605. 62745. 62775. 62995. 63430.
#  63885. 63465. 63320. 63635. 63230. 64030. 64100. 64225. 64500. 64495.
#  63960. 64100. 63030. 63615. 63610. 63685. 63830. 64500. 64415. 64530.
#  65045. 65520. 66300. 66085. 65275. 66040. 65225. 65880. 65845. 66065.
#  65865. 66340. 65620. 65375. 65230. 65160. 65455. 65620. 65520. 67015.
#  67705. 67445. 66935. 67360. 67055. 66145. 65365. 64300. 65055. 64645.]
# >>>> maximum drawdown: -3405.0
# >>>> profit (expense adjusted): 2948.9495
# >>>> holding period: 69.0 minutes
# >>>> standard deviation: 1369.925256787272
# >>>> sharpe: 2.15192896932492
# =========================================================================================================
# at time: 2023-12-06 13:35:00 || Buy  Call option of strike = 4690000.0 for a price of 62860.0
# at time: 2023-12-06 14:15:00 || Sell Call option of strike = 4690000.0 for a price of 63365.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [62860. 63110. 63800. 63975. 63500. 62585. 63230. 62070. 62595. 62710.
#  62910. 62920. 63920. 63965. 64675. 64735. 64025. 64425. 64150. 64265.
#  63900. 63110. 63540. 63935. 64000. 64620. 64250. 64695. 65100. 64785.
#  65380. 66085. 65500. 64415. 64795. 64110. 63500. 63465. 63555. 63695.
#  63365.]
# >>>> maximum drawdown: -2720.0
# >>>> profit (expense adjusted): 233.61625000000004
# >>>> holding period: 40.0 minutes
# >>>> standard deviation: 854.6486766500622
# >>>> sharpe: 0.272676004117279
# =========================================================================================================
# at time: 2023-12-06 14:15:00 || Buy  Put option of strike = 4700000.0 for a price of 62640.0
# at time: 2023-12-06 14:22:00 || Sell Put option of strike = 4700000.0 for a price of 62300.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [62640. 63020. 62240. 62760. 62670. 62135. 62240. 62300.]
# >>>> maximum drawdown: -885.0
# >>>> profit (expense adjusted): -608.621
# >>>> holding period: 7.0 minutes
# >>>> standard deviation: 294.7290864081793
# >>>> sharpe: -2.0653581124531586
# =========================================================================================================
# at time: 2023-12-06 14:22:00 || Buy  Call option of strike = 4700000.0 for a price of 59475.0
# at time: 2023-12-06 14:25:00 || Sell Call option of strike = 4700000.0 for a price of 58235.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [59475. 59180. 59125. 58235.]
# >>>> maximum drawdown: -1240.0
# >>>> profit (expense adjusted): -1493.0765
# >>>> holding period: 3.0 minutes
# >>>> standard deviation: 463.36237169196204
# >>>> sharpe: -3.222353232631451
# =========================================================================================================
# at time: 2023-12-06 14:25:00 || Buy  Put option of strike = 4700000.0 for a price of 63185.0
# at time: 2023-12-06 14:36:00 || Sell Put option of strike = 4700000.0 for a price of 61975.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [63185. 63900. 64760. 64415. 63895. 63060. 62650. 63435. 63345. 63000.
#  62725. 61975.]
# >>>> maximum drawdown: -2785.0
# >>>> profit (expense adjusted): -1479.0939999999998
# >>>> holding period: 11.0 minutes
# >>>> standard deviation: 749.0228588337978
# >>>> sharpe: -1.974909932779753
# =========================================================================================================
# at time: 2023-12-06 14:36:00 || Buy  Call option of strike = 4700000.0 for a price of 59020.0
# at time: 2023-12-06 15:01:00 || Sell Call option of strike = 4700000.0 for a price of 58750.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [59020. 59630. 59705. 59895. 60030. 60000. 60355. 60600. 60935. 61990.
#  61130. 61000. 60860. 61025. 61280. 60995. 61000. 62260. 61260. 61035.
#  60550. 60250. 60000. 59640. 58735. 58750.]
# >>>> maximum drawdown: -3525.0
# >>>> profit (expense adjusted): -523.2055
# >>>> holding period: 25.0 minutes
# >>>> standard deviation: 880.6000005375571
# >>>> sharpe: -0.5945291526533334
# =========================================================================================================
# at time: 2023-12-06 15:01:00 || Buy  Put option of strike = 4700000.0 for a price of 62915.0
# at time: 2023-12-07 09:40:00 || Sell Put option of strike = 4700000.0 for a price of 67675.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [62915. 64795. 63720. 63985. 63935. 65315. 63950. 64200. 64355. 63545.
#  63655. 63605. 64180. 63850. 63900. 64630. 65050. 64890. 65345. 64800.
#  64700. 64715. 64535. 63725. 63430. 64485. 64635. 64850. 66600. 67450.
#  78700. 73650. 72820. 74825. 75875. 73200. 75275. 76140. 75720. 77530.
#  77765. 76500. 77025. 77825. 78105. 76105. 76100. 75140. 74385. 70870.
#  71965. 72895. 71855. 70420. 67675.]
# >>>> maximum drawdown: -11025.0
# >>>> profit (expense adjusted): 4479.2315
# >>>> holding period: 1119.0 minutes
# >>>> standard deviation: 5469.026622567047
# >>>> sharpe: 0.8160790426320982
# =========================================================================================================
# at time: 2023-12-07 09:40:00 || Buy  Call option of strike = 4680000.0 for a price of 60000.0
# at time: 2023-12-07 09:46:00 || Sell Call option of strike = 4680000.0 for a price of 55065.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [60000. 57005. 58300. 57665. 56750. 55030. 55065.]
# >>>> maximum drawdown: -4970.0
# >>>> profit (expense adjusted): -5182.38975
# >>>> holding period: 6.0 minutes
# >>>> standard deviation: 1635.5420994837382
# >>>> sharpe: -3.1686570118963484
# =========================================================================================================
# at time: 2023-12-07 09:46:00 || Buy  Put option of strike = 4670000.0 for a price of 56900.0
# at time: 2023-12-07 09:54:00 || Sell Put option of strike = 4670000.0 for a price of 53845.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [56900. 56000. 55735. 56790. 57115. 56660. 55305. 55515. 53845.]
# >>>> maximum drawdown: -3270.0
# >>>> profit (expense adjusted): -3293.10175
# >>>> holding period: 8.0 minutes
# >>>> standard deviation: 974.303169791963
# >>>> sharpe: -3.3800625709180614
# =========================================================================================================
# at time: 2023-12-07 09:54:00 || Buy  Call option of strike = 4680000.0 for a price of 57695.0
# at time: 2023-12-07 10:04:00 || Sell Call option of strike = 4680000.0 for a price of 54975.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [57695. 58555. 57550. 57225. 57195. 56940. 56195. 56020. 54885. 56065.
#  54975.]
# >>>> maximum drawdown: -3670.0
# >>>> profit (expense adjusted): -2962.2405
# >>>> holding period: 10.0 minutes
# >>>> standard deviation: 1091.6107591933935
# >>>> sharpe: -2.713762390848209
# =========================================================================================================
# at time: 2023-12-07 10:04:00 || Buy  Put option of strike = 4680000.0 for a price of 61120.0
# at time: 2023-12-07 10:23:00 || Sell Put option of strike = 4680000.0 for a price of 58565.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [61120. 60145. 61340. 60855. 60600. 60655. 60050. 60200. 59645. 61085.
#  60955. 61195. 62030. 60810. 61085. 60615. 59715. 60300. 59115. 58565.]
# >>>> maximum drawdown: -3465.0
# >>>> profit (expense adjusted): -2812.32275
# >>>> holding period: 19.0 minutes
# >>>> standard deviation: 791.9179250402152
# >>>> sharpe: -3.551615380188878
# =========================================================================================================
# at time: 2023-12-07 10:23:00 || Buy  Call option of strike = 4680000.0 for a price of 55955.0
# at time: 2023-12-07 11:30:00 || Sell Call option of strike = 4680000.0 for a price of 65200.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [55955. 56525. 56020. 55660. 56745. 56075. 55930. 55750. 55440. 56295.
#  56795. 57960. 58370. 59200. 58725. 57890. 57310. 58005. 61160. 62690.
#  63340. 64000. 63945. 61710. 62410. 61500. 61135. 61620. 61055. 62500.
#  64235. 64975. 64375. 65905. 64715. 62775. 62945. 63055. 63865. 65165.
#  65450. 66595. 70675. 70695. 71520. 73965. 74125. 73535. 72430. 73195.
#  73035. 72900. 74700. 74080. 72990. 70960. 70400. 69720. 70585. 71655.
#  70560. 70945. 70700. 69000. 70465. 69045. 67500. 65200.]
# >>>> maximum drawdown: -9760.0
# >>>> profit (expense adjusted): 8984.516749999999
# >>>> holding period: 67.0 minutes
# >>>> standard deviation: 6034.168491307471
# >>>> sharpe: 1.4887984699620207
# =========================================================================================================
# at time: 2023-12-07 11:30:00 || Buy  Put option of strike = 4690000.0 for a price of 56025.0
# at time: 2023-12-07 11:47:00 || Sell Put option of strike = 4690000.0 for a price of 54600.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [56025. 55670. 55770. 55745. 55275. 54685. 53885. 53795. 54835. 55175.
#  55510. 55280. 54930. 54075. 54255. 53500. 54525. 54600.]
# >>>> maximum drawdown: -2525.0
# >>>> profit (expense adjusted): -1662.84375
# >>>> holding period: 17.0 minutes
# >>>> standard deviation: 731.3422570271598
# >>>> sharpe: -2.2739848308373842
# =========================================================================================================
# at time: 2023-12-07 11:47:00 || Buy  Call option of strike = 4700000.0 for a price of 57740.0
# at time: 2023-12-07 11:48:00 || Sell Call option of strike = 4700000.0 for a price of 56775.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [57740. 56775.]
# >>>> maximum drawdown: -965.0
# >>>> profit (expense adjusted): -1211.2072500000002
# >>>> holding period: 1.0 minutes
# >>>> standard deviation: 482.5
# >>>> sharpe: -2.510301414815341
# =========================================================================================================
# at time: 2023-12-07 11:48:00 || Buy  Put option of strike = 4700000.0 for a price of 59790.0
# at time: 2023-12-07 11:52:00 || Sell Put option of strike = 4700000.0 for a price of 58015.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [59790. 59700. 60375. 59405. 58015.]
# >>>> maximum drawdown: -2360.0
# >>>> profit (expense adjusted): -2028.28075
# >>>> holding period: 4.0 minutes
# >>>> standard deviation: 786.7312120413172
# >>>> sharpe: -2.5781808598604354
# =========================================================================================================
# at time: 2023-12-07 11:52:00 || Buy  Call option of strike = 4700000.0 for a price of 59660.0
# at time: 2023-12-07 12:21:00 || Sell Call option of strike = 4700000.0 for a price of 58410.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# >>>> standard deviation: 11189.695741404998
# >>>> sharpe: 2.4631500490373948
# =========================================================================================================
# at time: 2023-12-28 10:02:00 || Buy  Put option of strike = 4850000.0 for a price of 14330.0
# at time: 2023-12-28 10:47:00 || Sell Put option of strike = 4850000.0 for a price of 12250.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [14330. 14395. 20570. 22370. 20480. 22260. 20520. 17670. 17145. 17595.
#  20595. 21030. 21200. 18490. 19225. 18620. 17300. 16515. 14690. 15475.
#  16555. 18030. 14165. 15065. 15700. 16900. 17120. 15675. 15825. 14925.
#  17365. 17590. 14835. 14735. 14840. 15370. 14680. 15295. 16245. 17300.
#  15635. 14795. 15420. 15325. 14355. 12250.]
# >>>> maximum drawdown: -10120.0
# >>>> profit (expense adjusted): -2137.147
# >>>> holding period: 45.0 minutes
# >>>> standard deviation: 2390.0356911383005
# >>>> sharpe: -0.8942520121988093
# =========================================================================================================
# at time: 2023-12-28 10:47:00 || Buy  Call option of strike = 4850000.0 for a price of 10490.0
# at time: 2023-12-28 10:55:00 || Sell Call option of strike = 4850000.0 for a price of 6735.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [10490. 11370. 11155. 10915. 10230.  9685.  8465.  8320.  6735.]
# >>>> maximum drawdown: -4635.0
# >>>> profit (expense adjusted): -3792.03375
# >>>> holding period: 8.0 minutes
# >>>> standard deviation: 1472.2528298705113
# >>>> sharpe: -2.5756805032943104
# =========================================================================================================
# at time: 2023-12-28 10:55:00 || Buy  Put option of strike = 4840000.0 for a price of 11130.0
# at time: 2023-12-28 11:07:00 || Sell Put option of strike = 4840000.0 for a price of 7495.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [11130. 10740.  9890.  9790.  9340.  8780.  8675.  8015.  8725.  8245.
#   7580.  7435.  7495.]
# >>>> maximum drawdown: -3695.0
# >>>> profit (expense adjusted): -3675.0437500000003
# >>>> holding period: 12.0 minutes
# >>>> standard deviation: 1160.017980884922
# >>>> sharpe: -3.1681183427408146
# =========================================================================================================
# at time: 2023-12-28 11:07:00 || Buy  Call option of strike = 4850000.0 for a price of 7915.0
# at time: 2023-12-28 11:56:00 || Sell Call option of strike = 4850000.0 for a price of 9825.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [ 7915.  9350. 14000. 11980. 12535. 13490. 12595. 14465. 11265. 11270.
#  12500. 11410. 11935. 12000. 11490.  9685.  9985. 10490. 10795. 10475.
#  10905. 10745.  9860. 10435. 10095. 11170. 11305. 10455. 10270. 11000.
#   9545. 10480. 10660. 10970. 11605. 12050. 10875. 10720. 11105. 10630.
#  10985. 10450. 11005. 11625. 11215. 10890. 10880. 10585. 10675.  9825.]
# >>>> maximum drawdown: -4920.0
# >>>> profit (expense adjusted): 1871.859
# >>>> holding period: 49.0 minutes
# >>>> standard deviation: 1125.008928853456
# >>>> sharpe: 1.663782753354631
# =========================================================================================================
# at time: 2023-12-28 11:56:00 || Buy  Put option of strike = 4850000.0 for a price of 8990.0
# at time: 2023-12-28 11:59:00 || Sell Put option of strike = 4850000.0 for a price of 7400.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [8990. 8030. 7595. 7400.]
# >>>> maximum drawdown: -1590.0
# >>>> profit (expense adjusted): -1625.2385000000002
# >>>> holding period: 3.0 minutes
# >>>> standard deviation: 613.385839011629
# >>>> sharpe: -2.6496285929148002
# =========================================================================================================
# at time: 2023-12-28 11:59:00 || Buy  Call option of strike = 4850000.0 for a price of 10910.0
# at time: 2023-12-28 12:12:00 || Sell Call option of strike = 4850000.0 for a price of 10090.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [10910. 11250. 10725. 11130. 11725. 11275. 10600. 10355. 10890. 10480.
#  10515. 10250. 10215. 10090.]
# >>>> maximum drawdown: -1635.0
# >>>> profit (expense adjusted): -865.15
# >>>> holding period: 13.0 minutes
# >>>> standard deviation: 458.59813006374026
# >>>> sharpe: -1.8865807000963732
# =========================================================================================================
# at time: 2023-12-28 12:12:00 || Buy  Put option of strike = 4850000.0 for a price of 7800.0
# at time: 2023-12-28 12:22:00 || Sell Put option of strike = 4850000.0 for a price of 6710.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [7800. 7525. 8210. 8145. 8005. 7745. 8475. 7460. 7265. 7115. 6710.]
# >>>> maximum drawdown: -1765.0
# >>>> profit (expense adjusted): -1121.1965
# >>>> holding period: 10.0 minutes
# >>>> standard deviation: 500.73747266299694
# >>>> sharpe: -2.239126027969092
# =========================================================================================================
# at time: 2023-12-28 12:22:00 || Buy  Call option of strike = 4850000.0 for a price of 11255.0
# at time: 2023-12-28 12:57:00 || Sell Call option of strike = 4850000.0 for a price of 11360.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [11255. 11030. 11565. 12270. 11890. 12380. 14190. 13205. 12825. 12815.
#  12395. 13135. 12800. 12400. 11935. 12975. 12500. 12700. 13665. 12720.
#  12765. 12435. 12635. 13190. 12560. 14610. 14500. 14385. 14430. 13030.
#  11235. 10900. 11935. 11375. 11700. 11360.]
# >>>> maximum drawdown: -3710.0
# >>>> profit (expense adjusted): 56.37774999999999
# >>>> holding period: 35.0 minutes
# >>>> standard deviation: 985.6776335986037
# >>>> sharpe: 0.05710570156683715
# =========================================================================================================
# at time: 2023-12-28 12:57:00 || Buy  Put option of strike = 4860000.0 for a price of 9880.0
# at time: 2023-12-28 12:58:00 || Sell Put option of strike = 4860000.0 for a price of 8995.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [9880. 8995.]
# >>>> maximum drawdown: -885.0
# >>>> profit (expense adjusted): -925.58125
# >>>> holding period: 1.0 minutes
# >>>> standard deviation: 442.5
# >>>> sharpe: -2.0917141371926835
# =========================================================================================================
# at time: 2023-12-28 12:58:00 || Buy  Call option of strike = 4860000.0 for a price of 6715.0
# at time: 2023-12-28 13:00:00 || Sell Call option of strike = 4860000.0 for a price of 5790.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [6715. 6220. 5790.]
# >>>> maximum drawdown: -925.0
# >>>> profit (expense adjusted): -951.8857499999999
# >>>> holding period: 2.0 minutes
# >>>> standard deviation: 377.9403245075721
# >>>> sharpe: -2.5186220005771687
# =========================================================================================================
# at time: 2023-12-28 13:00:00 || Buy  Put option of strike = 4860000.0 for a price of 10275.0
# at time: 2023-12-28 13:09:00 || Sell Put option of strike = 4860000.0 for a price of 7440.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [10275.  9965.  9595.  9440.  9110.  9440.  9450.  9150.  9190.  7440.]
# >>>> maximum drawdown: -2835.0
# >>>> profit (expense adjusted): -2873.08725
# >>>> holding period: 9.0 minutes
# >>>> standard deviation: 712.1497384679714
# >>>> sharpe: -4.034416089507439
# =========================================================================================================
# at time: 2023-12-28 13:09:00 || Buy  Call option of strike = 4860000.0 for a price of 7765.0
# at time: 2023-12-28 13:24:00 || Sell Call option of strike = 4860000.0 for a price of 6080.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [7765. 7475. 7455. 7495. 7940. 8110. 7550. 7155. 6670. 6290. 5920. 6120.
#  6010. 6370. 6260. 6080.]
# >>>> maximum drawdown: -2190.0
# >>>> profit (expense adjusted): -1714.7667499999998
# >>>> holding period: 15.0 minutes
# >>>> standard deviation: 746.5979480910391
# >>>> sharpe: -2.2968096106482383
# =========================================================================================================
# at time: 2023-12-28 13:24:00 || Buy  Put option of strike = 4860000.0 for a price of 8490.0
# at time: 2023-12-28 13:26:00 || Sell Put option of strike = 4860000.0 for a price of 7930.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [8490. 8670. 7930.]
# >>>> maximum drawdown: -740.0
# >>>> profit (expense adjusted): -595.303
# >>>> holding period: 2.0 minutes
# >>>> standard deviation: 315.101394615906
# >>>> sharpe: -1.889254972793695
# =========================================================================================================
# at time: 2023-12-28 13:26:00 || Buy  Call option of strike = 4860000.0 for a price of 6670.0
# at time: 2023-12-28 13:27:00 || Sell Call option of strike = 4860000.0 for a price of 5170.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [6670. 5170.]
# >>>> maximum drawdown: -1500.0
# >>>> profit (expense adjusted): -1525.4560000000001
# >>>> holding period: 1.0 minutes
# >>>> standard deviation: 750.0
# >>>> sharpe: -2.0339433637747337
# =========================================================================================================
# at time: 2023-12-28 13:27:00 || Buy  Put option of strike = 4860000.0 for a price of 9675.0
# at time: 2023-12-28 14:04:00 || Sell Put option of strike = 4860000.0 for a price of 5865.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [ 9675. 10805.  9915.  6835.  7805.  8265.  7650.  9210.  9010.  9470.
#  10475.  8665.  8555.  8670.  8835.  8035.  8790.  9040.  8675. 10795.
#   8980.  9770.  9695.  9095.  9930.  9735.  9350.  9420.  9905.  9780.
#   9550. 10170. 10935.  9735.  8870.  8940.  7120.  5865.]
# >>>> maximum drawdown: -5070.0
# >>>> profit (expense adjusted): -3843.411
# >>>> holding period: 37.0 minutes
# >>>> standard deviation: 1068.090109491919
# >>>> sharpe: -3.5984723529369353
# =========================================================================================================
# at time: 2023-12-28 14:04:00 || Buy  Call option of strike = 4860000.0 for a price of 5245.0
# at time: 2023-12-28 14:15:00 || Sell Call option of strike = 4860000.0 for a price of 1940.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [5245. 4685. 4195. 4315. 4750. 4910. 4965. 4255. 2910. 3190. 2985. 1940.]
# >>>> maximum drawdown: -3305.0
# >>>> profit (expense adjusted): -3320.44775
# >>>> holding period: 11.0 minutes
# >>>> standard deviation: 985.3703301297437
# >>>> sharpe: -3.369759389789242
# =========================================================================================================
# at time: 2023-12-28 14:15:00 || Buy  Put option of strike = 4850000.0 for a price of 5630.0
# at time: 2023-12-28 14:58:00 || Sell Put option of strike = 4850000.0 for a price of 1745.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [5630. 4685. 4990. 4870. 5865. 6430. 4675. 4445. 3275. 3610. 3730. 3525.
#  3170. 2720. 2550. 3210. 3355. 2805. 3370. 3520. 3620. 3705. 2880. 3285.
#  4065. 4325. 6095. 4050. 4155. 4320. 3985. 4425. 5325. 5295. 6770. 4885.
#  5615. 4925. 4730. 5720. 3590. 2385. 2130. 1745.]
# >>>> maximum drawdown: -5025.0
# >>>> profit (expense adjusted): -3900.85625
# >>>> holding period: 43.0 minutes
# >>>> standard deviation: 1162.5041266700061
# >>>> sharpe: -3.3556109025295773
# =========================================================================================================
# at time: 2023-12-28 14:58:00 || Buy  Call option of strike = 4850000.0 for a price of 3910.0
# at time: 2023-12-28 15:29:00 || Sell Call option of strike = 4850000.0 for a price of 960.0
# ==> TRADE STATS
# granularity/ variations in profits or open_prices during the holding period:
# [3910. 3050. 3550. 3600.  945. 1745. 1870. 1840. 1630. 1575. 1010. 1430.
#   970.  885. 1015.  820. 1050. 2560. 2055. 1935.  980.  755.  665.  840.
#  1140.  680.  885.  795. 1055.  905.  990.  960.]
# >>>> maximum drawdown: -3245.0
# >>>> profit (expense adjusted): -2960.4705
# >>>> holding period: 31.0 minutes
# >>>> standard deviation: 894.9553579779482
# >>>> sharpe: -3.3079841884011927
# =========================================================================================================
# -1.6561773100964754

# %%
class metrics: 
    def __init__(self, df_trades, df_call_put_open, df_call_put_close, fund_locked, risk_free_rate=12, transaction_costs=11.5, slippage = 10):
        self.fund_locked = fund_locked
        self.risk_free_rate = risk_free_rate
        self.df_trades = df_trades
        self.df_call_put_close = df_call_put_close
        self.df_call_put_open = df_call_put_open
        self.transaction_costs = transaction_costs
        self.slippage = slippage
    
    def get_expense_cost(self, amount):
        transaction_costs = self.transaction_costs
        slippage = self.slippage
        return amount * (transaction_costs + slippage)* 1/100 * 1/100
        
    def number_of_trades(self):
        return self.df_trades.count().iloc[0]

    def PNL(self):
        df_trades = self.df_trades
        profit, net_profit = 0, 0
        profits = []
        open_position = False
        for i, trade in df_trades.iterrows():
            price = trade['Price']
            position = trade['Position']
            cash_flow_nature = 1
            if position == 1: # long -> pos = 1, short -> pos = 0
                cash_flow_nature = -1
            net_profit += cash_flow_nature * price - self.get_expense_cost(price)
            profit += cash_flow_nature * price - self.get_expense_cost(price)
            if open_position and not position:
                profits.append(profit)
                profit = 0
            open_position = position
        return net_profit, profits

    def net_turnover(self):
        prices = self.df_trades['Price']
        return prices.sum()
        
    def net_expenditure(self):
        # 1% = 100 basis points => total_turnover * 0.01/100 * total_basis_points
        turnover = self.net_turnover()
        return self.get_expense_cost(turnover)

    def net_return(self):
        net_profit, _ = self.PNL()
        return 100 * net_profit/ self.fund_locked

    def sharpe(self):
        profits_per_day = self.per_day_pnl()
        profits_per_day = pd.Series(profits_per_day['pnl'])
        sharpe_ratio = profits_per_day.mean()
        sharpe_ratio -= self.fund_locked * self.risk_free_rate * 1/100 * 1/365
        sharpe_ratio /= profits_per_day.std()
        return sharpe_ratio

    def max_drawdown(self):
        _, profits = self.PNL()
        increments = [(profits[i] - profits[i - 1]) for i in range(1, len(profits))]
        dd = 0
        max_dd = 0
        for inc in increments:
            dd += inc
            dd = min(0, dd)
            max_dd = min(dd, max_dd)
        return max_dd
        
    def per_day_pnl(self):
        df_trades = self.df_trades
        df_call_put_close = self.df_call_put_close
        df_call_put_open = self.df_call_put_open
        trades_timestamps = df_trades.index.normalize().unique()
        pnl_per_day = []
        carry_over, carry_open_position = False, []
        expense = 0
        for date in trades_timestamps:
            pnl_this_day = 0
            df_trades_this_day = df_trades[df_trades.index.normalize() == date]
            if df_trades_this_day.empty and not carry_over:
                continue
            if df_trades_this_day.empty and carry_over:
                open_time = pd.Timestamp.combine(date, time(9, 15))
                close_time = pd.Timestamp.combine(date, time(15, 29))
                carry_opt_type = carry_open_position[1]
                carry_opt_strike = carry_open_position[2]
                pnl_this_day += df_call_put_open[carry_opt_type][carry_opt_strike].loc[close_time] - df_call_put_open[carry_opt_type][carry_opt_strike].loc[open_time]
                pnl_this_day -= self.get_expense_cost(df_call_put_open[carry_opt_type][carry_opt_strike].loc[close_time])
                pnl_per_day.append((date, pnl_this_day))
                continue
            if carry_over:
                call_put = df_trades_this_day["Call/Put"].iloc[0]
                strike = df_trades_this_day["strike_price"].iloc[0]
                carry_pivot_price = carry_open_position[0]
                pnl_this_day = df_trades_this_day["Price"].iloc[0] - carry_pivot_price
                pnl_this_day -= self.get_expense_cost(df_trades_this_day["Price"].iloc[0])
                df_trades_this_day = df_trades_this_day.iloc[1:]
                carry_over, carry_open_position = False, []
            df_prices = df_trades_this_day['Price']
            df_cashflow_nature = (-1) * df_trades_this_day['Position'] + (1) * (1 - df_trades_this_day['Position'])
            df_profits = df_prices * df_cashflow_nature
            df_expenses = self.get_expense_cost(df_prices)
            pnl_this_day += df_profits.sum() - df_expenses.sum()
            if df_trades_this_day['Position'].iloc[-1] == 1:
                call_put = df_trades_this_day['Call/Put'].iloc[-1]
                strike = df_trades_this_day['strike_price'].iloc[-1]
                date_timestamp = pd.Timestamp.combine(date, time(15, 29))
                carry_pivot_price = df_call_put_close[call_put][strike].loc[date_timestamp]
                carry_over, carry_open_position = True, [carry_pivot_price, call_put, strike]
                pnl_this_day += carry_pivot_price
            pnl_per_day.append((date, pnl_this_day))
        pnl_per_day = pd.DataFrame(pnl_per_day, columns=['date', 'pnl'])
        pnl_per_day.set_index('date', inplace=True)
        return pnl_per_day

# %%
# metrics = metrics(df_trades_test, profits_test, 100000, 12)
metrics = metrics(df_trades, df_call_put_open, df_call_put_close, fund_locked, 12, transaction_cost, slippage)

# %%
per_day_pnl = metrics.per_day_pnl()
per_day_pnl['pnl'] = per_day_pnl['pnl']/100
per_day_pnl
# Out:
#                    pnl
# date
# 2023-12-01 -206.463200
# 2023-12-04  902.982702
# 2023-12-05  183.884040
# 2023-12-06  -96.557958
# 2023-12-07 -260.333012
# 2023-12-08  -64.996533
# 2023-12-12  -23.035690
# 2023-12-13  -61.662582
# 2023-12-14  -20.489432
# 2023-12-18  -33.572452
# 2023-12-19  138.355918
# 2023-12-20  339.637855
# 2023-12-21   94.112000
# 2023-12-22  -91.360642
# 2023-12-26 -163.335513
# 2023-12-27  108.019978
# 2023-12-28 -206.327383

# %%
number_of_trades = metrics.number_of_trades()
sharpe = metrics.sharpe()
net_profit, _ = metrics.PNL()
net_expenditure = metrics.net_expenditure()
net_return = metrics.net_return()
max_drawdown = metrics.max_drawdown()

print("number of trades:", number_of_trades)
print("sharpe (adjusted for expenses):", sharpe)
print("net capital:", f"₹{fund_locked/100}")
print("net profit (accounted for expenses):", f"₹{net_profit/100}")
print(f"net expenditure (transaction costs = {transaction_cost} + slippage = {slippage}):", f"₹{net_expenditure/100}")
print("net return:", f"{net_return}%")
print("max drawdown in PNL:", f"₹{abs(max_drawdown)/100}")
# Out:
# number of trades: 360
# sharpe (adjusted for expenses): 0.11480322185027796
# net capital: ₹1000.0
# net profit (accounted for expenses): ₹538.8580950000002
# net expenditure (transaction costs = 11.5 + slippage = 10): ₹328.64190499999995
# net return: 53.88580950000002%
# max drawdown in PNL: ₹767.6635850000004

# %%
def draw_downs(profits):
    dd = 0
    max_dd = 0
    increments = [(profits[i] - profits[i-1]) for i in range(1, len(profits))]
    dds = []
    dd_falls = 0
    falls_peak_height = 0
    peak = 0
    max_dds_peak_height = 0
    max_dds_peak = 0
    max_dds_peak_temp = 0
    max_dds_peak_height_temp = 0
    max_dds_trough_temp = 0
    max_dds_trough_height_temp = 0
    max_dds_trough_depth = 0
    max_dds_peak_till_now = 0
    max_dds_peak_height_till_now = 0
    max_dds_trough_till_now = 0
    max_dds_trough_depth_till_now = 0
    max_dd_till_now = 0
    max_dds_trough = 0
    began = False
    for i, inc in enumerate(increments): 
        # ending of individual drawdowns
        if(inc > 0 and dd_falls != 0):
            dds.append((dd_falls, (peak, falls_peak_height), (i, profits[i])))
            dd_falls = 0
            began = False
        # marking the beginning of the downfall
        if(inc <= 0):
            if began == False:
                peak = i
                falls_peak_height = profits[i]
            began = True
            peak = min(peak, i)
            dd_falls += inc
        # tracking maximum drawdown
        dd += inc
        if(dd > 0):
            dd  = 0
            max_dds_peak_temp = i+1
            max_dds_peak_height_temp = profits[i+1]
        if(max_dd > dd):
            max_dd = dd
            max_dds_trough_temp = i+1
            max_dds_trough_depth_temp = profits[i+1]
        if(max_dd_till_now > max_dd):
            max_dds_peak_till_now = max_dds_peak_temp
            max_dds_peak_height_till_now = max_dds_peak_height_temp
            max_dds_trough_till_now = max_dds_trough_temp
            max_dds_trough_depth_till_now = max_dds_trough_depth_temp
            max_dd_till_now = max_dd 

    max_dd = [max_dd, (max_dds_peak_till_now, max_dds_peak_height_till_now), (max_dds_trough_till_now, max_dds_trough_depth_till_now)]
    return max_dd, dds

# %%
_, profits = metrics.PNL()
max_dd, dds = draw_downs(profits)
print(max_dd, dds)
# Out:
# [-72694.17575, (21, 67251.409), (22, -5442.76675)] [(-1164.9425, (0, -811.3779999999999), (1, -1976.3205)), (-2270.8435, (3, 1218.0035), (5, -1052.84)), (-2865.031, (6, -640.6685), (9, -3505.6995)), (-1791.6795, (12, -617.76475), (13, -2409.44425)), (-50860.0515, (15, 49077.83), (16, -1782.2215)), (-21624.847500000003, (17, 17394.99475), (18, -4229.85275)), (-72694.17575, (21, 67251.409), (22, -5442.76675)), (-10172.588749999999, (23, 6244.638), (24, -3927.95075)), (-3194.98925, (26, -892.94375), (27, -4087.933)), (-2769.89625, (29, -523.2055), (30, -3293.10175)), (-10647.3605, (31, 8984.51675), (32, -1662.84375)), (-916.7964999999999, (33, -1504.804), (34, -2421.6005)), (-1787.61475, (35, -1316.892), (36, -3104.50675)), (-240.817, (37, -792.20875), (38, -1033.02575)), (-5445.68225, (40, 3396.739), (41, -2048.94325)), (-1222.0235000000002, (42, -1044.513), (44, -2266.5365)), (-13089.599, (46, 10607.65975), (48, -2481.93925)), (-66749.21925, (49, 64699.879), (51, -2049.34025)), (-13371.253250000002, (52, 8325.3075), (53, -5045.94575)), (-1853.5929999999998, (56, -227.543), (57, -2081.136)), (-1616.3665, (60, 255.29125), (61, -1361.07525)), (-3596.6295, (62, -640.754), (64, -4237.3835)), (-2993.0555, (66, 1871.859), (67, -1121.1965))]

# %%
plt.figure(figsize=(12,6))
plt.plot(profits)
for dd in dds:
    plt.plot(dd[1][0], dd[1][1], marker='v', color='r')
    plt.plot(dd[2][0], dd[2][1], marker='^', color='g')
plt.plot([max_dd[1][0], max_dd[2][0]], [max_dd[1][1], max_dd[2][1]], marker = '.', linestyle='--', color='black', label='max drawdown')
plt.grid(True)
plt.title("Profit/Loss on every position completion")
plt.xlabel("xth completed trade")
plt.ylabel("Profit/Loss")
plt.legend()
plt.show()

# %%
def plot_futures_and_ema(df, start_date, end_date):
    symbol = df['symbol'].iloc[0]
    start = pd.to_datetime(start_date)
    end = pd.to_datetime(end_date)
    df = df.copy()
    df = df.loc[start:end]
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['close']/100, color='black', label='close price')
    plt.plot(df.index, df['short']/100, color='green', label='short EMA')
    plt.plot(df.index, df['long']/100, color='red', label='long EMA')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.title(f'{symbol} Future Close Prices Over Time')
    plt.xlabel('Time')
    plt.ylabel('Close Price (in Rs)')
    plt.tight_layout() 
    plt.legend()
    plt.show()

# %%
plot_futures_and_ema(df_futures, '2023-12-20', '2023-12-21')

# %%
def plot_options_and_trades(df_options, df_options_in_ram, opt_type, start_date, df_trades, filter_ticks):
    symbol = df_options['symbol'].iloc[0]
    
    start = pd.to_datetime(start_date)
    # end = pd.to_datetime(end_date)
    
    df_lala_options = df_options_in_ram[opt_type].copy()
    # df_lala_options = df_lala_options.loc[start:end]
    df_lala_options = df_lala_options[df_lala_options.index.date == start.date()]

    df_lala_trades = df_trades[df_trades['Call/Put'] == opt_type]
    # df_lala_trades = df_lala_trades.copy().loc[start:end]
    df_lala_trades = df_lala_trades[df_lala_trades.index.date == start.date()]

    strikes_traded = df_lala_trades['strike_price'].unique()
    num_strikes = len(strikes_traded)
    cols = 1
    rows = (num_strikes// cols) + (num_strikes % cols > 0)

    figure, axes = plt.subplots(rows, cols, figsize=(15, 5*rows), squeeze = False)
    axes = axes.flatten()
    
    for i, strike in enumerate(strikes_traded):
        ax = axes[i]
        ax.plot(df_lala_options.index, df_lala_options[strike]/100)
        trade_lines = df_lala_trades['strike_price'] == strike
        trade_lines = df_lala_trades[trade_lines]

        start_loop = int(trade_lines['Position'].iloc[0] == 0)
        for j in range(start_loop, len(trade_lines)-1, 2):
            ax.plot([trade_lines.index[j], trade_lines.index[j+1]], [trade_lines['Price'].iloc[j]/100, trade_lines['Price'].iloc[j+1]/100], color = 'green', marker="o")
            # ax.plot(trade_lines.index[j], trade_lines['Price'].iloc[j]/100, color = 'green', marker="o")
            # ax.plot(trade_lines.index[j+1], trade_lines['Price'].iloc[j+1]/100, color = 'green', marker="o")

        name = "Put"
        if opt_type:
            name = "Call"
        ax.set_title(f"{name} Options price and trades with strike = {strike}")
        ax.set_xlabel("time stamps")
        ax.set_ylabel("close prices in Rs")
        ax.tick_params(axis='x', rotation=45)
        ax.legend()
 
        # ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M'))
        ax.xaxis.set_major_locator(mdates.AutoDateLocator())
        ax.xaxis.set_major_formatter(FuncFormatter(filter_ticks))
   
    for j in range(len(strikes_traded), len(axes)):
        figure.delaxes(axes[j])

    plt.tight_layout() 
    plt.show()

# %%
def filter_ticks(x, pos=None):
    dt = mdates.num2date(x)
    if dt.hour < 9 or (dt.hour == 15 and dt.minute > 29) or dt.hour > 15:
        return ''
    return dt.strftime('%Y-%m-%d %H:%M')

# %%
def plot_all_traded_options(df_options, df_ram, start, df_trades, filter_ticks):
    plot_options_and_trades(df_options, df_ram, 1, start, df_trades, filter_ticks)
    plot_options_and_trades(df_options, df_ram, 0, start, df_trades, filter_ticks)

# %%
plot_all_traded_options(df_options, df_call_put_close, '2023-12-05', df_trades, filter_ticks)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
