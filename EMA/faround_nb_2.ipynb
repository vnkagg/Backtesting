# %%
import psycopg2
import pandas as pd

# %%
from matplotlib import pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import FuncFormatter

# %%
host="192.168.2.23"
port=5432
user="amt"
dbname="qdap_test"

# %%
def make_connection_to_db(host, port, user, dbname):
    conn = psycopg2.connect(host= host, port=port, user=user, dbname=dbname)
    cursor = conn.cursor()
    return cursor, conn

# %%
def fetch_options_data(cursor, symbol, strike_price, date, month, year, type):
    cursor.execute(
        f'''
            SELECT *
            FROM ohlcv_options_per_minute oopm
            WHERE symbol = '{option}' 
            AND strike = {strike_price} 
            AND extract(year from oopm.expiry) = {year} 
            AND extract(month from oopm.expiry) = {month}
            AND extract(day from oopm.expiry) = {date}
            AND opt_type = '{type}';
        '''
    )
    rows = cursor.fetchall()
    df = pd.DataFrame(rows, columns=[desc[0] for desc in cursor.description])
    return df

def fetch_options_data(cursor, symbol, expiry):
    cursor.execute(
        f'''
            SELECT *
            FROM ohlcv_options_per_minute oopm
            WHERE symbol = '{symbol}' 
            AND expiry_type = 'I'
            AND expiry = (
                SELECT MAX(oopmm.expiry)
                FROM ohlcv_options_per_minute oopmm
                WHERE oopmm.symbol = '{symbol}'
                AND oopmm.expiry_type = 'I'
                AND oopmm.expiry <= '{expiry}'
            )
            ORDER BY date_timestamp ASC;
            
        '''
    )
    rows = cursor.fetchall()
    df = pd.DataFrame(rows, columns=[desc[0] for desc in cursor.description])
    return df

# %%
def fetch_futures_data(cursor, symbol, x=0):
    query = f'''
        SELECT *
        FROM ohlcv_future_per_minute ofpm
        WHERE ofpm.symbol = '{symbol}'
        AND ofpm.expiry_type = 'I'
        AND ofpm.expiry = (
            SELECT ofpmm.expiry 
            FROM ohlcv_future_per_minute ofpmm
            WHERE ofpmm.symbol = '{symbol}'
            AND ofpmm.expiry_type = 'I'
            GROUP BY ofpmm.expiry
            OFFSET {x}
            LIMIT 1
        )
        ORDER BY date_timestamp ASC;
    '''
    cursor.execute(query)
    rows = cursor.fetchall()
    df = pd.DataFrame(rows, columns=[desc[0] for desc in cursor.description])
    return df

# %%
def fetch_equity_data(cursor, symbol, begin, expiry):
    query = f'''
        SELECT *
        FROM ohlcv_cm_per_minute ocpm
        WHERE ocpm.symbol = '{symbol}'
        AND date_timestamp <= '{expiry}'
        AND date_timestamp >= '{begin}'
        ORDER BY date_timestamp ASC;
    '''
    cursor.execute(query)
    rows = cursor.fetchall()
    df = pd.DataFrame(rows, columns=[desc[0] for desc in cursor.description])
    return df

# %%
def fetch(host, port, user, dbname, symbol, x=15):
    cursor, conn = make_connection_to_db(host, port, user, dbname)
    # hardcoded for near month expiry
    df_futures = fetch_futures_data(cursor, symbol, x) # date is the expiry
    expiry = df_futures['expiry'].iloc[0]
    df_options = fetch_options_data(cursor, symbol, expiry)
    cursor.close()
    conn.close()
    return df_futures, df_options

# %%
symbol = "ADANIENT"
x = 20 # index of the array of all the unique expiries of I futures.

# %%
DF_FUTURES, DF_OPTIONS = fetch(host, port, user, dbname, symbol, x)

# %%
# ====================================================================================================================================== #

# %%
df_futures = DF_FUTURES.copy()
df_options = DF_OPTIONS.copy()

# %%
df_futures = df_futures.drop_duplicates(subset='date_timestamp', keep='first')
df_options = df_options.drop_duplicates(subset=['date_timestamp', 'strike'], keep='first')
df_futures.set_index('date_timestamp', inplace=True)
df_options.set_index('date_timestamp', inplace=True)
df_futures
# Out:
#                        symbol    open     low    high   close  volume  \
# date_timestamp
# 2023-12-01 09:15:00  ADANIENT  239600  238490  240300  239000   55800
# 2023-12-01 09:16:00  ADANIENT  239045  239045  239885  239505   50400
# 2023-12-01 09:17:00  ADANIENT  239745  239000  239800  239690   25200
# 2023-12-01 09:18:00  ADANIENT  239690  238690  239900  238740   38400
# 2023-12-01 09:19:00  ADANIENT  239000  238400  239000  238400   34800
# ...                       ...     ...     ...     ...     ...     ...
# 2023-12-28 15:25:00  ADANIENT  281000  280990  281500  281200   26700
# 2023-12-28 15:26:00  ADANIENT  281395  280980  281935  281095    9300
# 2023-12-28 15:27:00  ADANIENT  280890  280825  281500  281215    7500
# 2023-12-28 15:28:00  ADANIENT  281595  281495  282010  281645   10200
# 2023-12-28 15:29:00  ADANIENT  281700  281700  282105  282035   17700
#
#                                  expiry expiry_type        id
# date_timestamp
# 2023-12-01 09:15:00 2023-12-28 14:30:00           I  13451483
# 2023-12-01 09:16:00 2023-12-28 14:30:00           I  60246387
# 2023-12-01 09:17:00 2023-12-28 14:30:00           I  13451485
# 2023-12-01 09:18:00 2023-12-28 14:30:00           I  60246389
# 2023-12-01 09:19:00 2023-12-28 14:30:00           I  13451487
# ...                                 ...         ...       ...
# 2023-12-28 15:25:00 2023-12-28 14:30:00           I  62099001
# 2023-12-28 15:26:00 2023-12-28 14:30:00           I  15304099
# 2023-12-28 15:27:00 2023-12-28 14:30:00           I  62099003
# 2023-12-28 15:28:00 2023-12-28 14:30:00           I  15304101
# 2023-12-28 15:29:00 2023-12-28 14:30:00           I  62099005
#
# [7040 rows x 9 columns]

# %%
# NOTE THAT OPTIONS AND FUTURES EXPIRY IN THE QDAP DATABASE ARE NOT FOLLOWING THE SAME FORMAT.
expiry_options = pd.Timestamp(df_options['expiry'].iloc[0]).date()
expiry_futures = pd.Timestamp(df_futures['expiry'].iloc[0]).date()
starts_options = pd.Timestamp(df_options.index[0]).date()
starts_futures = pd.Timestamp(df_futures.index[0]).date()

start_intersection = max(starts_options, starts_futures)
end_intersection = min(expiry_options, expiry_futures)
start_intersection = pd.Timestamp.combine(start_intersection, pd.Timestamp('09:15:00').time())
end_intersection = pd.Timestamp.combine(end_intersection, pd.Timestamp('15:29:00').time())

print("starts_options:", starts_options)
print("expiry_options:", expiry_options)
print("starts_futures:", starts_futures)
print("expiry_futures:", expiry_futures)
print("start_intersection:", start_intersection)
print("end_intersection:", end_intersection)

range_futures = (df_futures.index <= end_intersection) & (df_futures.index >= start_intersection)
range_options = (df_options.index <= end_intersection) & (df_options.index >= start_intersection)

df_futures = df_futures[range_futures]
df_options = df_options[range_options]
# df_futures = df_futures[range_futures]
# df_options = df_options[range_options]
# Out:
# starts_options: 2023-12-01
# expiry_options: 2023-12-28
# starts_futures: 2023-12-01
# expiry_futures: 2023-12-28
# start_intersection: 2023-12-01 09:15:00
# end_intersection: 2023-12-28 15:29:00

# %%
df_futures
# Out:
#                        symbol    open     low    high   close  volume  \
# date_timestamp
# 2023-12-01 09:15:00  ADANIENT  239600  238490  240300  239000   55800
# 2023-12-01 09:16:00  ADANIENT  239045  239045  239885  239505   50400
# 2023-12-01 09:17:00  ADANIENT  239745  239000  239800  239690   25200
# 2023-12-01 09:18:00  ADANIENT  239690  238690  239900  238740   38400
# 2023-12-01 09:19:00  ADANIENT  239000  238400  239000  238400   34800
# ...                       ...     ...     ...     ...     ...     ...
# 2023-12-28 15:25:00  ADANIENT  281000  280990  281500  281200   26700
# 2023-12-28 15:26:00  ADANIENT  281395  280980  281935  281095    9300
# 2023-12-28 15:27:00  ADANIENT  280890  280825  281500  281215    7500
# 2023-12-28 15:28:00  ADANIENT  281595  281495  282010  281645   10200
# 2023-12-28 15:29:00  ADANIENT  281700  281700  282105  282035   17700
#
#                                  expiry expiry_type        id
# date_timestamp
# 2023-12-01 09:15:00 2023-12-28 14:30:00           I  13451483
# 2023-12-01 09:16:00 2023-12-28 14:30:00           I  60246387
# 2023-12-01 09:17:00 2023-12-28 14:30:00           I  13451485
# 2023-12-01 09:18:00 2023-12-28 14:30:00           I  60246389
# 2023-12-01 09:19:00 2023-12-28 14:30:00           I  13451487
# ...                                 ...         ...       ...
# 2023-12-28 15:25:00 2023-12-28 14:30:00           I  62099001
# 2023-12-28 15:26:00 2023-12-28 14:30:00           I  15304099
# 2023-12-28 15:27:00 2023-12-28 14:30:00           I  62099003
# 2023-12-28 15:28:00 2023-12-28 14:30:00           I  15304101
# 2023-12-28 15:29:00 2023-12-28 14:30:00           I  62099005
#
# [7040 rows x 9 columns]

# %%
df_options
# Out:
#                        symbol   open   high    low  close  volume opt_type  \
# date_timestamp
# 2023-12-01 09:15:00  ADANIENT  15200  15400  15120  15400     900       CE
# 2023-12-01 09:15:00  ADANIENT   6865   7335   6685   6800   11400       CE
# 2023-12-01 09:15:00  ADANIENT   2950   2970   2750   2910    1800       PE
# 2023-12-01 09:15:00  ADANIENT  17920  17920  17725  17725     300       CE
# 2023-12-01 09:15:00  ADANIENT   3800   3800   3570   3630    1200       PE
# ...                       ...    ...    ...    ...    ...     ...      ...
# 2023-12-28 15:28:00  ADANIENT  21800  21800  21800  21800     900       CE
# 2023-12-28 15:29:00  ADANIENT      5      5      5      5     900       CE
# 2023-12-28 15:29:00  ADANIENT   2000   2000   2000   2000    1500       CE
# 2023-12-28 15:29:00  ADANIENT  21800  21800  21800  21800     600       CE
# 2023-12-28 15:29:00  ADANIENT      5      5      5      5    1200       CE
#
#                      strike expiry_type         id      expiry
# date_timestamp
# 2023-12-01 09:15:00  235000           I  136893346  2023-12-28
# 2023-12-01 09:15:00  260000           I  136895942  2023-12-28
# 2023-12-01 09:15:00  205000           I  136891457  2023-12-28
# 2023-12-01 09:15:00  230000           I  136892754  2023-12-28
# 2023-12-01 09:15:00  210000           I  136891652  2023-12-28
# ...                     ...         ...        ...         ...
# 2023-12-28 15:28:00  260000           I  158875144  2023-12-28
# 2023-12-28 15:29:00  300000           I  158878414  2023-12-28
# 2023-12-28 15:29:00  280000           I  158875967  2023-12-28
# 2023-12-28 15:29:00  260000           I  158875145  2023-12-28
# 2023-12-28 15:29:00  290000           I  158877202  2023-12-28
#
# [139915 rows x 11 columns]

# %%
df_calls = df_options[(df_options['opt_type'] == 'CE')]
df_puts  = df_options[(df_options['opt_type'] == 'PE')]

# %%
df_calls_ram = df_calls.pivot(columns='strike', values='close').ffill()
df_puts_ram = df_puts.pivot(columns='strike', values='close').ffill()

# %%
print(df_calls_ram.shape)
print(df_puts_ram.shape)
print(df_futures.shape)
# Out:
# (7122, 33)
# (7096, 34)
# (7040, 9)

# %%
market_holidays = [
    (1, 26), (3, 8), (3, 29), (4, 19), (5, 1),
    (8, 15), (10, 2), (10, 24), (11, 12), (12, 25)
]

trading_days = pd.date_range(start=start_intersection, end=end_intersection, freq='B')
trading_days = trading_days[~trading_days.to_series().apply(lambda x: (x.month, x.day) in market_holidays)]

# Generate a complete range of trading minutes for each trading day
trading_minutes = pd.date_range(start='09:15:00', end='15:29:00', freq='T').time

# Create a complete index of trading timestamps
complete_index = pd.DatetimeIndex([pd.Timestamp.combine(day, time) for day in trading_days for time in trading_minutes])


df_futures = df_futures.reindex(complete_index).ffill()
df_calls_ram = df_calls_ram.reindex(complete_index).ffill()
df_puts_ram = df_puts_ram.reindex(complete_index).ffill()
# Out:
# C:\Users\user4\AppData\Local\Temp\8\ipykernel_33024\3754155990.py:10: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   trading_minutes = pd.date_range(start='09:15:00', end='15:29:00', freq='T').time

# %%
print(df_calls_ram.shape)
print(df_puts_ram.shape)
print(df_futures.shape)
# Out:
# (7125, 33)
# (7125, 34)
# (7125, 9)

# %%
df = [df_puts_ram, df_calls_ram]

# %%
df_futures
# Out:
#                        symbol      open       low      high     close  \
# 2023-12-01 09:15:00  ADANIENT  239600.0  238490.0  240300.0  239000.0
# 2023-12-01 09:16:00  ADANIENT  239045.0  239045.0  239885.0  239505.0
# 2023-12-01 09:17:00  ADANIENT  239745.0  239000.0  239800.0  239690.0
# 2023-12-01 09:18:00  ADANIENT  239690.0  238690.0  239900.0  238740.0
# 2023-12-01 09:19:00  ADANIENT  239000.0  238400.0  239000.0  238400.0
# ...                       ...       ...       ...       ...       ...
# 2023-12-28 15:25:00  ADANIENT  281000.0  280990.0  281500.0  281200.0
# 2023-12-28 15:26:00  ADANIENT  281395.0  280980.0  281935.0  281095.0
# 2023-12-28 15:27:00  ADANIENT  280890.0  280825.0  281500.0  281215.0
# 2023-12-28 15:28:00  ADANIENT  281595.0  281495.0  282010.0  281645.0
# 2023-12-28 15:29:00  ADANIENT  281700.0  281700.0  282105.0  282035.0
#
#                       volume              expiry expiry_type          id
# 2023-12-01 09:15:00  55800.0 2023-12-28 14:30:00           I  13451483.0
# 2023-12-01 09:16:00  50400.0 2023-12-28 14:30:00           I  60246387.0
# 2023-12-01 09:17:00  25200.0 2023-12-28 14:30:00           I  13451485.0
# 2023-12-01 09:18:00  38400.0 2023-12-28 14:30:00           I  60246389.0
# 2023-12-01 09:19:00  34800.0 2023-12-28 14:30:00           I  13451487.0
# ...                      ...                 ...         ...         ...
# 2023-12-28 15:25:00  26700.0 2023-12-28 14:30:00           I  62099001.0
# 2023-12-28 15:26:00   9300.0 2023-12-28 14:30:00           I  15304099.0
# 2023-12-28 15:27:00   7500.0 2023-12-28 14:30:00           I  62099003.0
# 2023-12-28 15:28:00  10200.0 2023-12-28 14:30:00           I  15304101.0
# 2023-12-28 15:29:00  17700.0 2023-12-28 14:30:00           I  62099005.0
#
# [7125 rows x 9 columns]

# %%
df_calls_ram
# Out:
# strike                190000   200000   205000   210000   215000   220000  \
# 2023-12-01 09:15:00      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-12-01 09:16:00      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-12-01 09:17:00      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-12-01 09:18:00      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-12-01 09:19:00      NaN      NaN      NaN      NaN      NaN  24100.0
# ...                      ...      ...      ...      ...      ...      ...
# 2023-12-28 15:25:00  90000.0  84000.0  91925.0  73500.0  63790.0  60500.0
# 2023-12-28 15:26:00  90000.0  84000.0  91925.0  73500.0  63790.0  60500.0
# 2023-12-28 15:27:00  90000.0  84000.0  91925.0  73500.0  63790.0  60500.0
# 2023-12-28 15:28:00  90000.0  84000.0  91925.0  73500.0  63790.0  60500.0
# 2023-12-28 15:29:00  90000.0  84000.0  91925.0  73500.0  63790.0  60500.0
#
# strike                225000   230000   235000   240000  ...  310000  315000  \
# 2023-12-01 09:15:00      NaN  17725.0  15400.0      NaN  ...     NaN     NaN
# 2023-12-01 09:16:00      NaN  17725.0  15700.0      NaN  ...     NaN     NaN
# 2023-12-01 09:17:00      NaN  18450.0  15700.0  13490.0  ...     NaN     NaN
# 2023-12-01 09:18:00      NaN  17815.0  15700.0  13490.0  ...     NaN     NaN
# 2023-12-01 09:19:00  20700.0  17815.0  15700.0  12510.0  ...     NaN     NaN
# ...                      ...      ...      ...      ...  ...     ...     ...
# 2023-12-28 15:25:00  60000.0  51000.0  47300.0  41240.0  ...     5.0     5.0
# 2023-12-28 15:26:00  60000.0  51000.0  47300.0  41240.0  ...     5.0     5.0
# 2023-12-28 15:27:00  60000.0  51000.0  47300.0  41240.0  ...     5.0     5.0
# 2023-12-28 15:28:00  60000.0  51000.0  47300.0  41240.0  ...     5.0     5.0
# 2023-12-28 15:29:00  60000.0  51000.0  47300.0  41240.0  ...     5.0     5.0
#
# strike               320000  325000  330000  335000  340000  345000  350000  \
# 2023-12-01 09:15:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2023-12-01 09:16:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2023-12-01 09:17:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2023-12-01 09:18:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2023-12-01 09:19:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2023-12-28 15:25:00     5.0     5.0     5.0     5.0     5.0     5.0     5.0
# 2023-12-28 15:26:00     5.0     5.0     5.0     5.0     5.0     5.0     5.0
# 2023-12-28 15:27:00     5.0     5.0     5.0     5.0     5.0     5.0     5.0
# 2023-12-28 15:28:00     5.0     5.0     5.0     5.0     5.0     5.0     5.0
# 2023-12-28 15:29:00     5.0     5.0     5.0     5.0     5.0     5.0     5.0
#
# strike               355000
# 2023-12-01 09:15:00     NaN
# 2023-12-01 09:16:00     NaN
# 2023-12-01 09:17:00     NaN
# 2023-12-01 09:18:00     NaN
# 2023-12-01 09:19:00     NaN
# ...                     ...
# 2023-12-28 15:25:00     5.0
# 2023-12-28 15:26:00     5.0
# 2023-12-28 15:27:00     5.0
# 2023-12-28 15:28:00     5.0
# 2023-12-28 15:29:00     5.0
#
# [7125 rows x 33 columns]

# %%
df_puts_ram
# Out:
# strike               175000  180000  185000  190000  195000  200000  205000  \
# 2023-12-01 09:15:00  1220.0  1360.0     NaN  2020.0     NaN  2515.0  2910.0
# 2023-12-01 09:16:00  1345.0  1360.0     NaN  2295.0     NaN  2620.0  3080.0
# 2023-12-01 09:17:00  1300.0  1360.0     NaN  2125.0     NaN  2650.0  3165.0
# 2023-12-01 09:18:00  1380.0  1360.0     NaN  1970.0     NaN  2595.0  3100.0
# 2023-12-01 09:19:00  1380.0  1360.0     NaN  1960.0     NaN  2625.0  3100.0
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2023-12-28 15:25:00    20.0    15.0     5.0    30.0     5.0     5.0     5.0
# 2023-12-28 15:26:00    20.0    15.0     5.0    30.0     5.0     5.0     5.0
# 2023-12-28 15:27:00    20.0    15.0     5.0    30.0     5.0     5.0     5.0
# 2023-12-28 15:28:00     5.0    15.0     5.0    30.0     5.0     5.0     5.0
# 2023-12-28 15:29:00     5.0    15.0     5.0    30.0     5.0     5.0     5.0
#
# strike               210000  215000  220000  ...   295000   300000   305000  \
# 2023-12-01 09:15:00  3630.0     NaN  5790.0  ...      NaN      NaN      NaN
# 2023-12-01 09:16:00  3635.0     NaN  5670.0  ...      NaN      NaN      NaN
# 2023-12-01 09:17:00  3785.0     NaN  5650.0  ...      NaN      NaN      NaN
# 2023-12-01 09:18:00  3745.0     NaN  5630.0  ...      NaN      NaN      NaN
# 2023-12-01 09:19:00  3800.0     NaN  5630.0  ...      NaN      NaN      NaN
# ...                     ...     ...     ...  ...      ...      ...      ...
# 2023-12-28 15:25:00     5.0     5.0     5.0  ...  14100.0  18005.0  23335.0
# 2023-12-28 15:26:00     5.0     5.0     5.0  ...  14100.0  18505.0  23335.0
# 2023-12-28 15:27:00     5.0     5.0     5.0  ...  14100.0  18505.0  23335.0
# 2023-12-28 15:28:00     5.0     5.0     5.0  ...  14100.0  18505.0  23335.0
# 2023-12-28 15:29:00     5.0     5.0     5.0  ...  14100.0  18505.0  23335.0
#
# strike                310000   315000   320000   325000   330000   335000  \
# 2023-12-01 09:15:00      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-12-01 09:16:00      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-12-01 09:17:00      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-12-01 09:18:00      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-12-01 09:19:00      NaN      NaN      NaN      NaN      NaN      NaN
# ...                      ...      ...      ...      ...      ...      ...
# 2023-12-28 15:25:00  28700.0  31770.0  36700.0  37910.0  47500.0  50350.0
# 2023-12-28 15:26:00  28700.0  31770.0  36700.0  37910.0  47500.0  50350.0
# 2023-12-28 15:27:00  28700.0  31770.0  36700.0  37910.0  47500.0  50350.0
# 2023-12-28 15:28:00  28700.0  31770.0  36700.0  37910.0  47500.0  50350.0
# 2023-12-28 15:29:00  28700.0  31770.0  36700.0  37910.0  47500.0  50350.0
#
# strike                350000
# 2023-12-01 09:15:00      NaN
# 2023-12-01 09:16:00      NaN
# 2023-12-01 09:17:00      NaN
# 2023-12-01 09:18:00      NaN
# 2023-12-01 09:19:00      NaN
# ...                      ...
# 2023-12-28 15:25:00  65520.0
# 2023-12-28 15:26:00  65520.0
# 2023-12-28 15:27:00  65520.0
# 2023-12-28 15:28:00  65520.0
# 2023-12-28 15:29:00  65520.0
#
# [7125 rows x 34 columns]

# %%
def ema(window_short, window_long, df):
    df.loc[:,'short'] = df['close'].ewm(window_short).mean()
    df.loc[:,'long'] = df['close'].ewm(window_long).mean() 
    polarity = df['short'] - df['long']
    polarity = polarity > 0
    signals = []
    position_polarity_positive = polarity.iloc[0]
    for i in range(0, df.shape[0]):
        if(polarity.iloc[i] != position_polarity_positive):
            position_polarity_positive = polarity.iloc[i]
            signals.append((int(position_polarity_positive), df.index[i], df.index[i+1]))
            # bullish -> (1, signal_time, valid_trade_time), bearish -> (0, signal_time, valid_trade_time)
    return signals

# %%
window_short = 9
window_long = 26
signals = ema(window_short, window_long, df_futures)
print(len(signals))
# bullish -> (1, signal_time, valid_trade_time), bearish -> (0, signal_time, valid_trade_time)
print(signals)
# Out:
# 176
# [(1, Timestamp('2023-12-01 09:16:00'), Timestamp('2023-12-01 09:17:00')), (0, Timestamp('2023-12-01 09:18:00'), Timestamp('2023-12-01 09:19:00')), (1, Timestamp('2023-12-01 09:27:00'), Timestamp('2023-12-01 09:28:00')), (0, Timestamp('2023-12-01 09:52:00'), Timestamp('2023-12-01 09:53:00')), (1, Timestamp('2023-12-01 10:28:00'), Timestamp('2023-12-01 10:29:00')), (0, Timestamp('2023-12-01 11:03:00'), Timestamp('2023-12-01 11:04:00')), (1, Timestamp('2023-12-01 11:33:00'), Timestamp('2023-12-01 11:34:00')), (0, Timestamp('2023-12-01 11:55:00'), Timestamp('2023-12-01 11:56:00')), (1, Timestamp('2023-12-01 13:06:00'), Timestamp('2023-12-01 13:07:00')), (0, Timestamp('2023-12-01 13:15:00'), Timestamp('2023-12-01 13:16:00')), (1, Timestamp('2023-12-01 13:28:00'), Timestamp('2023-12-01 13:29:00')), (0, Timestamp('2023-12-01 14:46:00'), Timestamp('2023-12-01 14:47:00')), (1, Timestamp('2023-12-04 09:15:00'), Timestamp('2023-12-04 09:16:00')), (0, Timestamp('2023-12-04 10:42:00'), Timestamp('2023-12-04 10:43:00')), (1, Timestamp('2023-12-04 10:44:00'), Timestamp('2023-12-04 10:45:00')), (0, Timestamp('2023-12-04 13:43:00'), Timestamp('2023-12-04 13:44:00')), (1, Timestamp('2023-12-04 13:57:00'), Timestamp('2023-12-04 13:58:00')), (0, Timestamp('2023-12-04 14:25:00'), Timestamp('2023-12-04 14:26:00')), (1, Timestamp('2023-12-05 09:17:00'), Timestamp('2023-12-05 09:18:00')), (0, Timestamp('2023-12-05 11:44:00'), Timestamp('2023-12-05 11:45:00')), (1, Timestamp('2023-12-05 12:23:00'), Timestamp('2023-12-05 12:24:00')), (0, Timestamp('2023-12-06 09:52:00'), Timestamp('2023-12-06 09:53:00')), (1, Timestamp('2023-12-06 09:57:00'), Timestamp('2023-12-06 09:58:00')), (0, Timestamp('2023-12-06 10:30:00'), Timestamp('2023-12-06 10:31:00')), (1, Timestamp('2023-12-06 10:35:00'), Timestamp('2023-12-06 10:36:00')), (0, Timestamp('2023-12-06 11:05:00'), Timestamp('2023-12-06 11:06:00')), (1, Timestamp('2023-12-06 12:11:00'), Timestamp('2023-12-06 12:12:00')), (0, Timestamp('2023-12-06 12:14:00'), Timestamp('2023-12-06 12:15:00')), (1, Timestamp('2023-12-06 13:41:00'), Timestamp('2023-12-06 13:42:00')), (0, Timestamp('2023-12-06 14:07:00'), Timestamp('2023-12-06 14:08:00')), (1, Timestamp('2023-12-06 14:29:00'), Timestamp('2023-12-06 14:30:00')), (0, Timestamp('2023-12-06 14:31:00'), Timestamp('2023-12-06 14:32:00')), (1, Timestamp('2023-12-07 09:21:00'), Timestamp('2023-12-07 09:22:00')), (0, Timestamp('2023-12-07 09:53:00'), Timestamp('2023-12-07 09:54:00')), (1, Timestamp('2023-12-07 10:56:00'), Timestamp('2023-12-07 10:57:00')), (0, Timestamp('2023-12-07 11:46:00'), Timestamp('2023-12-07 11:47:00')), (1, Timestamp('2023-12-07 12:04:00'), Timestamp('2023-12-07 12:05:00')), (0, Timestamp('2023-12-07 12:49:00'), Timestamp('2023-12-07 12:50:00')), (1, Timestamp('2023-12-07 13:21:00'), Timestamp('2023-12-07 13:22:00')), (0, Timestamp('2023-12-07 13:24:00'), Timestamp('2023-12-07 13:25:00')), (1, Timestamp('2023-12-07 14:16:00'), Timestamp('2023-12-07 14:17:00')), (0, Timestamp('2023-12-07 14:24:00'), Timestamp('2023-12-07 14:25:00')), (1, Timestamp('2023-12-07 14:31:00'), Timestamp('2023-12-07 14:32:00')), (0, Timestamp('2023-12-07 14:32:00'), Timestamp('2023-12-07 14:33:00')), (1, Timestamp('2023-12-07 15:10:00'), Timestamp('2023-12-07 15:11:00')), (0, Timestamp('2023-12-08 09:28:00'), Timestamp('2023-12-08 09:29:00')), (1, Timestamp('2023-12-08 09:40:00'), Timestamp('2023-12-08 09:41:00')), (0, Timestamp('2023-12-08 10:26:00'), Timestamp('2023-12-08 10:27:00')), (1, Timestamp('2023-12-08 14:04:00'), Timestamp('2023-12-08 14:05:00')), (0, Timestamp('2023-12-11 10:41:00'), Timestamp('2023-12-11 10:42:00')), (1, Timestamp('2023-12-11 11:03:00'), Timestamp('2023-12-11 11:04:00')), (0, Timestamp('2023-12-11 12:36:00'), Timestamp('2023-12-11 12:37:00')), (1, Timestamp('2023-12-11 12:41:00'), Timestamp('2023-12-11 12:42:00')), (0, Timestamp('2023-12-11 12:42:00'), Timestamp('2023-12-11 12:43:00')), (1, Timestamp('2023-12-11 12:44:00'), Timestamp('2023-12- ...

# %%
def make_trades(signals, expiry, df_futures, df_options, df, fund_locked):
    available_funds = fund_locked
    trades = []
    # (number, 1/0, 1/0, t, s)
    # (price, call/put, long/short, timestamp, strike) 
    ix = 0
    while ix < len(signals):    
        first_signal_type = signals[ix][0]
        first_valid_tradable_timestamp = signals[ix][2]
        futures_price = df_futures['close'].loc[first_valid_tradable_timestamp]
        # Finding the ITM-1 or ATM option 
        strike = futures_price
        if first_signal_type:
            eligible_candidates = df_options[(df_options.index == first_valid_tradable_timestamp) & (df_options['strike'] <= strike)]
            strike = eligible_candidates["strike"].max()
        else:
            eligible_candidates = df_options[(df_options.index == first_valid_tradable_timestamp) & (df_options['strike'] >= strike)]
            strike = eligible_candidates["strike"].min()
        price = df[first_signal_type][strike].loc[first_valid_tradable_timestamp]
        if price <= available_funds:
            trades.append((price, first_signal_type, 1, first_valid_tradable_timestamp, strike))
            available_funds -= price
            break
        ix += 1
    for i, signal in enumerate(signals[ix+1:]):
        last_trade = trades[len(trades) - 1]
        last_trade_price = last_trade[0]
        last_trade_opt_type = last_trade[1]
        last_trade_position = last_trade[2]
        last_strike = last_trade[4]
        signal_nature = signal[0]
        signal_time_stamp = signal[1]
        valid_tradable_time_stamp = signal[2]
        square_off_price = df[last_trade_opt_type][last_strike].loc[valid_tradable_time_stamp]
        current_strike = df_futures['close'].loc[valid_tradable_time_stamp]
        if first_signal_type:
            eligible_candidates = df_options[(df_options.index == first_valid_tradable_timestamp) & (df_options['strike'] <= current_strike)]
            current_strike = eligible_candidates["strike"].max()
        else:
            eligible_candidates = df_options[(df_options.index == first_valid_tradable_timestamp) & (df_options['strike'] >= currrent_strike)]
            current_strike = eligible_candidates["strike"].min()

        buying_price = df[signal_nature][current_strike].loc[valid_tradable_time_stamp]
        if last_trade_position == 1:
            trades.append((square_off_price, last_trade_opt_type, 1-last_trade_position, valid_tradable_time_stamp, last_strike))
            available_funds += min(square_off_price, last_trade_price)
        if buying_price <= available_funds:
            trades.append((buying_price, signal_nature, 1, valid_tradable_time_stamp, current_strike))
            available_funds -= buying_price

    last_trade = trades[len(trades) - 1]
    last_trade_opt_type = last_trade[1]
    last_trade_strike = last_trade[4]
    expiry = pd.to_datetime(expiry, format = '%d-%m-%Y')
    last_valid_tradable_time_stamp = pd.Timestamp(f"{expiry} 15:29:00")
    last_square_off_price = df[last_trade_opt_type][last_trade_strike].loc[last_valid_tradable_time_stamp]
    trades.append((last_square_off_price, last_trade_opt_type, 0, last_valid_tradable_time_stamp, last_trade_strike))
    return trades

# %%
trades = make_trades(signals, end_intersection, df_futures, df_options, df, 100000000)
df_trades = pd.DataFrame(trades, columns=['Price', 'Call/Put', 'Position', 'date_timestamp', 'strike_price'])
df_trades = df_trades.set_index('date_timestamp')
print(len(trades))
df_trades
# Out:
# 352
#                        Price  Call/Put  Position  strike_price
# date_timestamp
# 2023-12-01 09:17:00  15700.0         1         1        235000
# 2023-12-01 09:19:00  15700.0         1         0        235000
# 2023-12-01 09:19:00  11245.0         0         1        235000
# 2023-12-01 09:28:00  11040.0         0         0        235000
# 2023-12-01 09:28:00  15730.0         1         1        235000
# ...                      ...       ...       ...           ...
# 2023-12-28 14:05:00    115.0         0         0        280000
# 2023-12-28 14:05:00   3925.0         1         1        280000
# 2023-12-28 14:10:00   3810.0         1         0        280000
# 2023-12-28 14:10:00    110.0         0         1        280000
# 2023-12-28 15:29:00      5.0         0         0        280000
#
# [352 rows x 4 columns]

# %%
def print_trades(df_trades):
    for i, row in df_trades.iterrows():
        pos = "Sell"
        if row["Position"]:
            pos = "Buy"
        type = "Put"
        if row["Call/Put"]:
            type = "Call"
        strike = row["strike_price"]
        price = row["Price"]
        print(f"{pos} {type} option of strike = {strike} for a price of {price}")

# %%
print_trades(df_trades)
# Out:
# Buy Call option of strike = 235000.0 for a price of 15700.0
# Sell Call option of strike = 235000.0 for a price of 15700.0
# Buy Put option of strike = 235000.0 for a price of 11245.0
# Sell Put option of strike = 235000.0 for a price of 11040.0
# Buy Call option of strike = 235000.0 for a price of 15730.0
# Sell Call option of strike = 235000.0 for a price of 14640.0
# Buy Put option of strike = 235000.0 for a price of 11080.0
# Sell Put option of strike = 235000.0 for a price of 10300.0
# Buy Call option of strike = 240000.0 for a price of 14000.0
# Sell Call option of strike = 240000.0 for a price of 12565.0
# Buy Put option of strike = 235000.0 for a price of 11265.0
# Sell Put option of strike = 235000.0 for a price of 11090.0
# Buy Call option of strike = 235000.0 for a price of 15355.0
# Sell Call option of strike = 235000.0 for a price of 14900.0
# Buy Put option of strike = 235000.0 for a price of 11130.0
# Sell Put option of strike = 235000.0 for a price of 11325.0
# Buy Call option of strike = 235000.0 for a price of 14640.0
# Sell Call option of strike = 235000.0 for a price of 14455.0
# Buy Put option of strike = 235000.0 for a price of 11425.0
# Sell Put option of strike = 235000.0 for a price of 11350.0
# Buy Call option of strike = 235000.0 for a price of 14700.0
# Sell Call option of strike = 235000.0 for a price of 14890.0
# Buy Put option of strike = 235000.0 for a price of 11170.0
# Sell Put option of strike = 235000.0 for a price of 3225.0
# Buy Call option of strike = 255000.0 for a price of 12950.0
# Sell Call option of strike = 255000.0 for a price of 11375.0
# Buy Put option of strike = 250000.0 for a price of 11300.0
# Sell Put option of strike = 250000.0 for a price of 11225.0
# Buy Call option of strike = 250000.0 for a price of 13635.0
# Sell Call option of strike = 250000.0 for a price of 14800.0
# Buy Put option of strike = 255000.0 for a price of 12110.0
# Sell Put option of strike = 255000.0 for a price of 11500.0
# Buy Call option of strike = 255000.0 for a price of 13080.0
# Sell Call option of strike = 255000.0 for a price of 12590.0
# Buy Put option of strike = 255000.0 for a price of 11980.0
# Sell Put option of strike = 255000.0 for a price of 10900.0
# Buy Call option of strike = 255000.0 for a price of 13500.0
# Sell Call option of strike = 255000.0 for a price of 28805.0
# Buy Put option of strike = 270000.0 for a price of 13230.0
# Sell Put option of strike = 270000.0 for a price of 12695.0
# Buy Call option of strike = 270000.0 for a price of 21235.0
# Sell Call option of strike = 270000.0 for a price of 40000.0
# Buy Put option of strike = 290000.0 for a price of 19000.0
# Sell Put option of strike = 290000.0 for a price of 17550.0
# Buy Call option of strike = 290000.0 for a price of 31735.0
# Sell Call option of strike = 290000.0 for a price of 28400.0
# Buy Put option of strike = 290000.0 for a price of 17900.0
# Sell Put option of strike = 290000.0 for a price of 17900.0
# Buy Call option of strike = 290000.0 for a price of 31380.0
# Sell Call option of strike = 290000.0 for a price of 29500.0
# Buy Put option of strike = 290000.0 for a price of 17880.0
# Sell Put option of strike = 290000.0 for a price of 16530.0
# Buy Call option of strike = 290000.0 for a price of 27520.0
# Sell Call option of strike = 290000.0 for a price of 27520.0
# Buy Put option of strike = 290000.0 for a price of 16605.0
# Sell Put option of strike = 290000.0 for a price of 18600.0
# Buy Call option of strike = 290000.0 for a price of 23680.0
# Sell Call option of strike = 290000.0 for a price of 22275.0
# Buy Put option of strike = 290000.0 for a price of 19900.0
# Sell Put option of strike = 290000.0 for a price of 18990.0
# Buy Call option of strike = 290000.0 for a price of 22400.0
# Sell Call option of strike = 290000.0 for a price of 22005.0
# Buy Put option of strike = 290000.0 for a price of 19205.0
# Sell Put option of strike = 290000.0 for a price of 18790.0
# Buy Call option of strike = 290000.0 for a price of 22355.0
# Sell Call option of strike = 290000.0 for a price of 20665.0
# Buy Put option of strike = 290000.0 for a price of 19800.0
# Sell Put option of strike = 290000.0 for a price of 18745.0
# Buy Call option of strike = 290000.0 for a price of 19600.0
# Sell Call option of strike = 290000.0 for a price of 19090.0
# Buy Put option of strike = 285000.0 for a price of 16195.0
# Sell Put option of strike = 285000.0 for a price of 15875.0
# Buy Call option of strike = 290000.0 for a price of 19525.0
# Sell Call option of strike = 290000.0 for a price of 19880.0
# Buy Put option of strike = 290000.0 for a price of 18450.0
# Sell Put option of strike = 290000.0 for a price of 18110.0
# Buy Call option of strike = 290000.0 for a price of 20450.0
# Sell Call option of strike = 290000.0 for a price of 19800.0
# Buy Put option of strike = 290000.0 for a price of 18120.0
# Sell Put option of strike = 290000.0 for a price of 18335.0
# Buy Call option of strike = 290000.0 for a price of 19700.0
# Sell Call option of strike = 290000.0 for a price of 19330.0
# Buy Put option of strike = 290000.0 for a price of 18300.0
# Sell Put option of strike = 290000.0 for a price of 18270.0
# Buy Call option of strike = 290000.0 for a price of 19420.0
# Sell Call option of strike = 290000.0 for a price of 19420.0
# Buy Put option of strike = 290000.0 for a price of 18355.0
# Sell Put option of strike = 290000.0 for a price of 18205.0
# Buy Call option of strike = 290000.0 for a price of 19385.0
# Sell Call option of strike = 290000.0 for a price of 18245.0
# Buy Put option of strike = 285000.0 for a price of 16240.0
# Sell Put option of strike = 285000.0 for a price of 14700.0
# Buy Call option of strike = 290000.0 for a price of 19600.0
# Sell Call option of strike = 290000.0 for a price of 18800.0
# Buy Put option of strike = 290000.0 for a price of 17410.0
# Sell Put option of strike = 290000.0 for a price of 21000.0
# Buy Call option of strike = 280000.0 for a price of 15800.0
# Sell Call option of strike = 280000.0 for a price of 16520.0
# Buy Put option of strike = 280000.0 for a price of 11870.0
# Sell Put option of strike = 280000.0 for a price of 10765.0
# Buy Call option of strike = 285000.0 for a price of 15000.0
# Sell Call option of strike = 285000.0 for a price of 18450.0
# Buy Put option of strike = 290000.0 for a price of 15810.0
# Sell Put option of strike = 290000.0 for a price of 15565.0
# Buy Call option of strike = 290000.0 for a price of 16415.0
# Sell Call option of strike = 290000.0 for a price of 16400.0
# Buy Put option of strike = 290000.0 for a price of 15565.0
# Sell Put option of strike = 290000.0 for a price of 15565.0
# Buy Call option of strike = 290000.0 for a price of 16400.0
# Sell Call option of strike = 290000.0 for a price of 16400.0
# Buy Put option of strike = 290000.0 for a price of 15555.0
# Sell Put option of strike = 290000.0 for a price of 16420.0
# Buy Call option of strike = 285000.0 for a price of 17485.0
# Sell Call option of strike = 285000.0 for a price of 16180.0
# Buy Put option of strike = 285000.0 for a price of 13410.0
# Sell Put option of strike = 285000.0 for a price of 11930.0
# Buy Call option of strike = 290000.0 for a price of 16080.0
# Sell Call option of strike = 290000.0 for a price of 14400.0
# Buy Put option of strike = 285000.0 for a price of 13100.0
# Sell Put option of strike = 285000.0 for a price of 13045.0
# Buy Call option of strike = 285000.0 for a price of 17095.0
# Sell Call option of strike = 285000.0 for a price of 16525.0
# Buy Put option of strike = 285000.0 for a price of 12825.0
# Sell Put option of strike = 285000.0 for a price of 13080.0
# Buy Call option of strike = 285000.0 for a price of 16265.0
# Sell Call option of strike = 285000.0 for a price of 15815.0
# Buy Put option of strike = 285000.0 for a price of 12930.0
# Sell Put option of strike = 285000.0 for a price of 12605.0
# Buy Call option of strike = 285000.0 for a price of 16390.0
# Sell Call option of strike = 285000.0 for a price of 15775.0
# Buy Put option of strike = 285000.0 for a price of 13200.0
# Sell Put option of strike = 285000.0 for a price of 12890.0
# Buy Call option of strike = 285000.0 for a price of 15925.0
# Sell Call option of strike = 285000.0 for a price of 15850.0
# Buy Put option of strike = 285000.0 for a price of 12890.0
# Sell Put option of strike = 285000.0 for a price of 12900.0
# Buy Call option of strike = 285000.0 for a price of 16120.0
# Sell Call option of strike = 285000.0 for a price of 15800.0
# Buy Put option of strike = 285000.0 for a price of 12955.0
# Sell Put option of strike = 285000.0 for a price of 12210.0
# Buy Call option of strike = 285000.0 for a price of 15985.0
# Sell Call option of strike = 285000.0 for a price of 15385.0
# Buy Put option of strike = 285000.0 for a price of 12895.0
# Sell Put option of strike = 285000.0 for a price of 12245.0
# Buy Call option of strike = 285000.0 for a price of 15890.0
# Sell Call option of strike = 285000.0 for a price of 14990.0
# Buy Put option of strike = 285000.0 for a price of 12580.0
# Sell Put option of strike = 285000.0 for a price of 13700.0
# Buy Call option of strike = 280000.0 for a price of 15500.0
# Sell Call option of strike = 280000.0 for a price of 17000.0
# Buy Put option of strike = 285000.0 for a price of 12000.0
# Sell Put option of strike = 285000.0 for a price of 11595.0
# Buy Call option of strike = 285000.0 for a price of 15450.0
# Sell Call option of strike = 285000.0 for a price of 16200.0
# Buy Put option of strike = 290000.0 for a price of 13095.0
# Sell Put option of strike = 290000.0 for a price of 12500.0
# Buy Call option of strike = 290000.0 for a price of 15100.0
# Sell Call option of strike = 290000.0 for a price of 14375.0
# Buy Put option of strike = 290000.0 for a price of 12775.0
# Sell Put option of strike = 290000.0 for a price of 11875.0
# Buy Call option of strike = 290000.0 for a price of 15345.0
# Sell Call option of strike = 290000.0 for a price of 14780.0
# Buy Put option of strike = 290000.0 for a price of 12835.0
# Sell Put option of strike = 290000.0 for a price of 11900.0
# Buy Call option of strike = 290000.0 for a price of 15970.0
# Sell Call option of strike = 290000.0 for a price of 15475.0
# Buy Put option of strike = 290000.0 for a price of 12280.0
# Sell Put option of strike = 290000.0 for a price of 11950.0
# Buy Call option of strike = 290000.0 for a price of 15740.0
# Sell Call option of strike = 290000.0 for a price of 15085.0
# Buy Put option of strike = 290000.0 for a price of 12200.0
# Sell Put option of strike = 290000.0 for a price of 11895.0
# Buy Call option of strike = 290000.0 for a price of 15300.0
# Sell Call option of strike = 290000.0 for a price of 15300.0
# Buy Put option of strike = 290000.0 for a price of 11905.0
# Sell Put option of strike = 290000.0 for a price of 11720.0
# Buy Call option of strike = 290000.0 for a price of 15700.0
# Sell Call option of strike = 290000.0 for a price of 15520.0
# Buy Put option of strike = 290000.0 for a price of 11845.0
# Sell Put option of strike = 290000.0 for a price of 11820.0
# Buy Call option of strike = 290000.0 for a price of 15600.0
# Sell Call option of strike = 290000.0 for a price of 15600.0
# Buy Put option of strike = 290000.0 for a price of 11800.0
# Sell Put option of strike = 290000.0 for a price of 11820.0
# Buy Call option of strike = 290000.0 for a price of 14500.0
# Sell Call option of strike = 290000.0 for a price of 15320.0
# Buy Put option of strike = 290000.0 for a price of 10200.0
# Sell Put option of strike = 290000.0 for a price of 9900.0
# Buy Call option of strike = 290000.0 for a price of 16235.0
# Sell Call option of strike = 290000.0 for a price of 17560.0
# Buy Put option of strike = 290000.0 for a price of 8285.0
# Sell Put option of strike = 290000.0 for a price of 8000.0
# Buy Call option of strike = 290000.0 for a price of 18760.0
# Sell Call option of strike = 290000.0 for a price of 17930.0
# Buy Put option of strike = 290000.0 for a price of 8440.0
# Sell Put option of strike = 290000.0 for a price of 7880.0
# Buy Call option of strike = 290000.0 for a price of 18225.0
# Sell Call option of strike = 290000.0 for a price of 18260.0
# Buy Put option of strike = 290000.0 for a price of 7780.0
# Sell Put option of strike = 290000.0 for a price of 6840.0
# Buy Call option of strike = 290000.0 for a price of 20555.0
# Sell Call option of strike = 290000.0 for a price of 18670.0
# Buy Put option of strike = 290000.0 for a price of 7525.0
# Sell Put option of strike = 290000.0 for a price of 7100.0
# Buy Call option of strike = 290000.0 for a price of 18400.0
# Sell Call option of strike = 290000.0 for a price of 17970.0
# Buy Put option of strike = 290000.0 for a price of 7225.0
# Sell Put option of strike = 290000.0 for a price of 7015.0
# Buy Call option of strike = 290000.0 for a price of 18130.0
# Sell Call option of strike = 290000.0 for a price of 18000.0
# Buy Put option of strike = 290000.0 for a price of 7250.0
# Sell Put option of strike = 290000.0 for a price of 7510.0
# Buy Call option of strike = 290000.0 for a price of 16970.0
# Sell Call option of strike = 290000.0 for a price of 16965.0
# Buy Put option of strike = 290000.0 for a price of 7545.0
# Sell Put option of strike = 290000.0 for a price of 7205.0
# Buy Call option of strike = 290000.0 for a price of 16965.0
# Sell Call option of strike = 290000.0 for a price of 17210.0
# Buy Put option of strike = 290000.0 for a price of 7350.0
# Sell Put option of strike = 290000.0 for a price of 8420.0
# Buy Call option of strike = 290000.0 for a price of 13475.0
# Sell Call option of strike = 290000.0 for a price of 13075.0
# Buy Put option of strike = 290000.0 for a price of 8565.0
# Sell Put option of strike = 290000.0 for a price of 8520.0
# Buy Call option of strike = 290000.0 for a price of 13360.0
# Sell Call option of strike = 290000.0 for a price of 14375.0
# Buy Put option of strike = 290000.0 for a price of 7415.0
# Sell Put option of strike = 290000.0 for a price of 7345.0
# Buy Call option of strike = 290000.0 for a price of 14320.0
# Sell Call option of strike = 290000.0 for a price of 14450.0
# Buy Put option of strike = 290000.0 for a price of 7230.0
# Sell Put option of strike = 290000.0 for a price of 7125.0
# Buy Call option of strike = 290000.0 for a price of 13600.0
# Sell Call option of strike = 290000.0 for a price of 13200.0
# Buy Put option of strike = 290000.0 for a price of 7075.0
# Sell Put option of strike = 290000.0 for a price of 6570.0
# Buy Call option of strike = 290000.0 for a price of 12550.0
# Sell Call option of strike = 290000.0 for a price of 12550.0
# Buy Put option of strike = 290000.0 for a price of 6475.0
# Sell Put option of strike = 290000.0 for a price of 6475.0
# Buy Call option of strike = 290000.0 for a price of 12750.0
# Sell Call option of strike = 290000.0 for a price of 11895.0
# Buy Put option of strike = 290000.0 for a price of 6565.0
# Sell Put option of strike = 290000.0 for a price of 14425.0
# Buy Call option of strike = 280000.0 for a price of 8505.0
# Sell Call option of strike = 280000.0 for a price of 6920.0
# Buy Put option of strike = 270000.0 for a price of 3420.0
# Sell Put option of strike = 270000.0 for a price of 3140.0
# Buy Call option of strike = 280000.0 for a price of 7315.0
# Sell Call option of strike = 280000.0 for a price of 7200.0
# Buy Put option of strike = 270000.0 for a price of 3005.0
# Sell Put option of strike = 270000.0 for a price of 2850.0
# Buy Call option of strike = 280000.0 for a price of 7365.0
# Sell Call option of strike = 280000.0 for a price of 7005.0
# Buy Put option of strike = 270000.0 for a price of 2860.0
# Sell Put option of strike = 270000.0 for a price of 2650.0
# Buy Call option of strike = 280000.0 for a price of 7255.0
# Sell Call option of strike = 280000.0 for a price of 6440.0
# Buy Put option of strike = 270000.0 for a price of 2950.0
# Sell Put option of strike = 270000.0 for a price of 2590.0
# Buy Call option of strike = 270000.0 for a price of 12100.0
# Sell Call option of strike = 270000.0 for a price of 12000.0
# Buy Put option of strike = 270000.0 for a price of 2750.0
# Sell Put option of strike = 270000.0 for a price of 2550.0
# Buy Call option of strike = 280000.0 for a price of 7380.0
# Sell Call option of strike = 280000.0 for a price of 7400.0
# Buy Put option of strike = 280000.0 for a price of 4255.0
# Sell Put option of strike = 280000.0 for a price of 3950.0
# Buy Call option of strike = 280000.0 for a price of 7920.0
# Sell Call option of strike = 280000.0 for a price of 7370.0
# Buy Put option of strike = 280000.0 for a price of 3660.0
# Sell Put option of strike = 280000.0 for a price of 3600.0
# Buy Call option of strike = 280000.0 for a price of 7325.0
# Sell Call option of strike = 280000.0 for a price of 7255.0
# Buy Put option of strike = 280000.0 for a price of 3690.0
# Sell Put option of strike = 280000.0 for a price of 4105.0
# Buy Call option of strike = 280000.0 for a price of 5780.0
# Sell Call option of strike = 280000.0 for a price of 5780.0
# Buy Put option of strike = 280000.0 for a price of 4105.0
# Sell Put option of strike = 280000.0 for a price of 4060.0
# Buy Call option of strike = 280000.0 for a price of 5780.0
# Sell Call option of strike = 280000.0 for a price of 5405.0
# Buy Put option of strike = 280000.0 for a price of 4210.0
# Sell Put option of strike = 280000.0 for a price of 3910.0
# Buy Call option of strike = 280000.0 for a price of 5870.0
# Sell Call option of strike = 280000.0 for a price of 5455.0
# Buy Put option of strike = 280000.0 for a price of 3655.0
# Sell Put option of strike = 280000.0 for a price of 2575.0
# Buy Call option of strike = 280000.0 for a price of 5585.0
# Sell Call option of strike = 280000.0 for a price of 7850.0
# Buy Put option of strike = 285000.0 for a price of 3755.0
# Sell Put option of strike = 285000.0 for a price of 3300.0
# Buy Call option of strike = 285000.0 for a price of 6010.0
# Sell Call option of strike = 285000.0 for a price of 5685.0
# Buy Put option of strike = 285000.0 for a price of 3270.0
# Sell Put option of strike = 285000.0 for a price of 3080.0
# Buy Call option of strike = 285000.0 for a price of 6100.0
# Sell Call option of strike = 285000.0 for a price of 5470.0
# Buy Put option of strike = 285000.0 for a price of 3245.0
# Sell Put option of strike = 285000.0 for a price of 2500.0
# Buy Call option of strike = 285000.0 for a price of 3765.0
# Sell Call option of strike = 285000.0 for a price of 3500.0
# Buy Put option of strike = 285000.0 for a price of 2795.0
# Sell Put option of strike = 285000.0 for a price of 2040.0
# Buy Call option of strike = 285000.0 for a price of 3475.0
# Sell Call option of strike = 285000.0 for a price of 3075.0
# Buy Put option of strike = 285000.0 for a price of 2510.0
# Sell Put option of strike = 285000.0 for a price of 2305.0
# Buy Call option of strike = 285000.0 for a price of 2815.0
# Sell Call option of strike = 285000.0 for a price of 2315.0
# Buy Put option of strike = 280000.0 for a price of 785.0
# Sell Put option of strike = 280000.0 for a price of 615.0
# Buy Call option of strike = 285000.0 for a price of 2970.0
# Sell Call option of strike = 285000.0 for a price of 2355.0
# Buy Put option of strike = 280000.0 for a price of 755.0
# Sell Put option of strike = 280000.0 for a price of 935.0
# Buy Call option of strike = 280000.0 for a price of 5055.0
# Sell Call option of strike = 280000.0 for a price of 4945.0
# Buy Put option of strike = 280000.0 for a price of 920.0
# Sell Put option of strike = 280000.0 for a price of 705.0
# Buy Call option of strike = 280000.0 for a price of 4910.0
# Sell Call option of strike = 280000.0 for a price of 4910.0
# Buy Put option of strike = 280000.0 for a price of 755.0
# Sell Put option of strike = 280000.0 for a price of 740.0
# Buy Call option of strike = 280000.0 for a price of 5250.0
# Sell Call option of strike = 280000.0 for a price of 5235.0
# Buy Put option of strike = 280000.0 for a price of 1125.0
# Sell Put option of strike = 280000.0 for a price of 990.0
# Buy Call option of strike = 280000.0 for a price of 5490.0
# Sell Call option of strike = 280000.0 for a price of 5335.0
# Buy Put option of strike = 280000.0 for a price of 1185.0
# Sell Put option of strike = 280000.0 for a price of 1210.0
# Buy Call option of strike = 280000.0 for a price of 5335.0
# Sell Call option of strike = 280000.0 for a price of 5495.0
# Buy Put option of strike = 280000.0 for a price of 1210.0
# Sell Put option of strike = 280000.0 for a price of 530.0
# Buy Call option of strike = 285000.0 for a price of 2590.0
# Sell Call option of strike = 285000.0 for a price of 1190.0
# Buy Put option of strike = 280000.0 for a price of 340.0
# Sell Put option of strike = 280000.0 for a price of 135.0
# Buy Call option of strike = 280000.0 for a price of 3390.0
# Sell Call option of strike = 280000.0 for a price of 2970.0
# Buy Put option of strike = 280000.0 for a price of 210.0
# Sell Put option of strike = 280000.0 for a price of 165.0
# Buy Call option of strike = 280000.0 for a price of 3070.0
# Sell Call option of strike = 280000.0 for a price of 3690.0
# Buy Put option of strike = 280000.0 for a price of 195.0
# Sell Put option of strike = 280000.0 for a price of 115.0
# Buy Call option of strike = 280000.0 for a price of 3925.0
# Sell Call option of strike = 280000.0 for a price of 3810.0
# Buy Put option of strike = 280000.0 for a price of 110.0
# Sell Put option of strike = 280000.0 for a price of 5.0

# %%
def PNL(trades):
    net_profit = 0
    profit = 0
    profits = []
    open_position = False
    for i, trade in enumerate(trades):
        price = trade[0]
        position = trade[2]
        cash_flow_nature = 1
        if position: # long -> pos = 1, short -> pos = 0
            cash_flow_nature = -1
        net_profit += cash_flow_nature * price
        profit += cash_flow_nature * price
        if open_position and ~position:
            profits.append(profit)
            profit = 0
        open_position = position
    return net_profit, profits

# %%
net_profit, profits = PNL(trades)
print(len(profits), net_profit, profits)
# Out:
# 176 -12330.0 [0.0, -205.0, -1090.0, -780.0, -1435.0, -175.0, -455.0, 195.0, -185.0, -75.0, 190.0, -7945.0, -1575.0, -75.0, 1165.0, -610.0, -490.0, -1080.0, 15305.0, -535.0, 18765.0, -1450.0, -3335.0, 0.0, -1880.0, -1350.0, 0.0, 1995.0, -1405.0, -910.0, -395.0, -415.0, -1690.0, -1055.0, -510.0, -320.0, 355.0, -340.0, -650.0, 215.0, -370.0, -30.0, 0.0, -150.0, -1140.0, -1540.0, -800.0, 3590.0, 720.0, -1105.0, 3450.0, -245.0, -15.0, 0.0, 0.0, 865.0, -1305.0, -1480.0, -1680.0, -55.0, -570.0, 255.0, -450.0, -325.0, -615.0, -310.0, -75.0, 10.0, -320.0, -745.0, -600.0, -650.0, -900.0, 1120.0, 1500.0, -405.0, 750.0, -595.0, -725.0, -900.0, -565.0, -935.0, -495.0, -330.0, -655.0, -305.0, 0.0, -185.0, -180.0, -25.0, 0.0, 20.0, 820.0, -300.0, 1325.0, -285.0, -830.0, -560.0, 35.0, -940.0, -1885.0, -425.0, -430.0, -210.0, -130.0, 260.0, -5.0, -340.0, 245.0, 1070.0, -400.0, -45.0, 1015.0, -70.0, 130.0, -105.0, -400.0, -505.0, 0.0, 0.0, -855.0, 7860.0, -1585.0, -280.0, -115.0, -155.0, -360.0, -210.0, -815.0, -360.0, -100.0, -200.0, 20.0, -305.0, -550.0, -60.0, -70.0, 415.0, 0.0, -45.0, -375.0, -300.0, -415.0, -1080.0, 2265.0, -455.0, -325.0, -190.0, -630.0, -745.0, -265.0, -755.0, -400.0, -205.0, -500.0, -170.0, -615.0, 180.0, -110.0, -215.0, 0.0, -15.0, -15.0, -135.0, -155.0, 25.0, 160.0, -680.0, -1400.0, -205.0, -420.0, -45.0, 620.0, -80.0, -115.0, -105.0]

# %%
def draw_downs(profits):
    dd = 0
    max_dd = 0
    increments = [(profits[i] - profits[i-1]) for i in range(1, len(profits))]
    dds = []
    dd_falls = 0
    falls_peak_height = 0
    peak = 0
    max_dds_peak_height = 0
    max_dds_peak = 0
    max_dds_peak_temp = 0
    max_dds_peak_height_temp = 0
    max_dds_trough_temp = 0
    max_dds_trough_height_temp = 0
    max_dds_trough_depth = 0
    max_dds_peak_till_now = 0
    max_dds_peak_height_till_now = 0
    max_dds_trough_till_now = 0
    max_dds_trough_depth_till_now = 0
    max_dd_till_now = 0
    max_dds_trough = 0
    began = False
    for i, inc in enumerate(increments): 
        # ending of individual drawdowns
        if(inc > 0 and dd_falls != 0):
            dds.append((dd_falls, (peak, falls_peak_height), (i, profits[i])))
            dd_falls = 0
            began = False
        # marking the beginning of the downfall
        if(inc <= 0):
            if began == False:
                peak = i
                falls_peak_height = profits[i]
            began = True
            peak = min(peak, i)
            dd_falls += inc
        # tracking maximum drawdown
        dd += inc
        if(dd > 0):
            dd  = 0
            max_dds_peak_temp = i+1
            max_dds_peak_height_temp = profits[i+1]
        if(max_dd > dd):
            max_dd = dd
            max_dds_trough_temp = i+1
            max_dds_trough_depth_temp = profits[i+1]
        if(max_dd_till_now > max_dd):
            max_dds_peak_till_now = max_dds_peak_temp
            max_dds_peak_height_till_now = max_dds_peak_height_temp
            max_dds_trough_till_now = max_dds_trough_temp
            max_dds_trough_depth_till_now = max_dds_trough_depth_temp
            max_dd_till_now = max_dd 

    max_dd = [max_dd, (max_dds_peak_till_now, max_dds_peak_height_till_now), (max_dds_trough_till_now, max_dds_trough_depth_till_now)]
    return max_dd, dds

# %%
max_dd, dds = draw_downs(profits)
print(max_dd, dds)
# Out:
# [-22100.0, (20, 18765.0), (22, -3335.0)] [(-1090.0, (0, 0.0), (2, -1090.0)), (-655.0, (3, -780.0), (4, -1435.0)), (-280.0, (5, -175.0), (6, -455.0)), (-380.0, (7, 195.0), (8, -185.0)), (-8135.0, (10, 190.0), (11, -7945.0)), (-1775.0, (14, 1165.0), (15, -610.0)), (-590.0, (16, -490.0), (17, -1080.0)), (-15840.0, (18, 15305.0), (19, -535.0)), (-22100.0, (20, 18765.0), (22, -3335.0)), (-1880.0, (23, 0.0), (24, -1880.0)), (-3400.0, (27, 1995.0), (28, -1405.0)), (-1295.0, (30, -395.0), (32, -1690.0)), (-1005.0, (36, 355.0), (38, -650.0)), (-585.0, (39, 215.0), (40, -370.0)), (-1540.0, (42, 0.0), (45, -1540.0)), (-4695.0, (47, 3590.0), (49, -1105.0)), (-3695.0, (50, 3450.0), (51, -245.0)), (-2545.0, (53, 0.0), (58, -1680.0)), (-515.0, (59, -55.0), (60, -570.0)), (-705.0, (61, 255.0), (62, -450.0)), (-290.0, (63, -325.0), (64, -615.0)), (-755.0, (67, 10.0), (69, -745.0)), (-300.0, (70, -600.0), (72, -900.0)), (-1905.0, (74, 1500.0), (75, -405.0)), (-1650.0, (76, 750.0), (79, -900.0)), (-370.0, (80, -565.0), (81, -935.0)), (-325.0, (83, -330.0), (84, -655.0)), (-185.0, (86, 0.0), (87, -185.0)), (-1120.0, (92, 820.0), (93, -300.0)), (-2155.0, (94, 1325.0), (96, -830.0)), (-1920.0, (98, 35.0), (100, -1885.0)), (-5.0, (101, -425.0), (102, -430.0)), (-600.0, (105, 260.0), (107, -340.0)), (-1470.0, (109, 1070.0), (110, -400.0)), (-1085.0, (112, 1015.0), (113, -70.0)), (-635.0, (114, 130.0), (117, -505.0)), (-855.0, (118, 0.0), (120, -855.0)), (-9445.0, (121, 7860.0), (122, -1585.0)), (-245.0, (124, -115.0), (126, -360.0)), (-605.0, (127, -210.0), (128, -815.0)), (-100.0, (130, -100.0), (131, -200.0)), (-570.0, (132, 20.0), (134, -550.0)), (-10.0, (135, -60.0), (136, -70.0)), (-790.0, (137, 415.0), (140, -375.0)), (-780.0, (141, -300.0), (143, -1080.0)), (-2720.0, (144, 2265.0), (145, -455.0)), (-555.0, (147, -190.0), (149, -745.0)), (-490.0, (150, -265.0), (151, -755.0)), (-295.0, (153, -205.0), (154, -500.0)), (-445.0, (155, -170.0), (156, -615.0)), (-395.0, (157, 180.0), (159, -215.0)), (-155.0, (160, 0.0), (164, -155.0)), (-1560.0, (166, 160.0), (168, -1400.0)), (-215.0, (169, -205.0), (170, -420.0)), (-735.0, (172, 620.0), (174, -115.0))]

# %%
plt.figure(figsize=(12,6))
plt.plot(profits)
for dd in dds:
    plt.plot(dd[1][0], dd[1][1], marker='v', color='r')
    plt.plot(dd[2][0], dd[2][1], marker='^', color='g')
plt.plot([max_dd[1][0], max_dd[2][0]], [max_dd[1][1], max_dd[2][1]], marker = '.', linestyle='--', color='black')
plt.grid(True)
plt.title("Profit/Loss on every position completion")
plt.xlabel("xth completed trade")
plt.ylabel("Profit/Loss")
plt.show()

# %%
def plot_futures_and_ema(df, start_date, end_date):
    symbol = df['symbol'].iloc[0]
    start = pd.to_datetime(start_date)
    end = pd.to_datetime(end_date)
    df = df.copy()
    df = df.loc[start:end]
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['close']/100, color='black')
    plt.plot(df.index, df['short']/100, color='green')
    plt.plot(df.index, df['long']/100, color='red')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.title(f'{symbol} Future Close Prices Over Time')
    plt.xlabel('Time')
    plt.ylabel('Close Price (in Rs)')
    plt.tight_layout() 
    plt.show()

# %%
plot_futures_and_ema(df_futures, '2023-12-20', '2023-12-21')

# %%
def plot_options_and_trades(df_options, df_options_in_ram, opt_type, start_date, df_trades, filter_ticks):
    symbol = df_options['symbol'].iloc[0]
    
    start = pd.to_datetime(start_date)
    # end = pd.to_datetime(end_date)
    
    df_lala_options = df_options_in_ram[opt_type].copy()
    # df_lala_options = df_lala_options.loc[start:end]
    df_lala_options = df_lala_options[df_lala_options.index.date == start.date()]

    df_lala_trades = df_trades[df_trades['Call/Put'] == opt_type]
    # df_lala_trades = df_lala_trades.copy().loc[start:end]
    df_lala_trades = df_lala_trades[df_lala_trades.index.date == start.date()]

    strikes_traded = df_lala_trades['strike_price'].unique()
    num_strikes = len(strikes_traded)
    cols = 1
    rows = (num_strikes// cols) + (num_strikes % cols > 0)

    figure, axes = plt.subplots(rows, cols, figsize=(15, 5*rows), squeeze = False)
    axes = axes.flatten()
    
    for i, strike in enumerate(strikes_traded):
        ax = axes[i]
        ax.plot(df_lala_options.index, df_lala_options[strike]/100)
        trade_lines = df_lala_trades['strike_price'] == strike
        trade_lines = df_lala_trades[trade_lines]

        start_loop = int(trade_lines['Position'].iloc[0] == 0)
        for j in range(start_loop, len(trade_lines)-1, 2):
            ax.plot([trade_lines.index[j], trade_lines.index[j+1]], [trade_lines['Price'].iloc[j]/100, trade_lines['Price'].iloc[j+1]/100], color = 'green', marker="o")
            # ax.plot(trade_lines.index[j], trade_lines['Price'].iloc[j]/100, color = 'green', marker="o")
            # ax.plot(trade_lines.index[j+1], trade_lines['Price'].iloc[j+1]/100, color = 'green', marker="o")

        name = "Put"
        if opt_type:
            name = "Call"
        ax.set_title(f"{name} Options price and trades with strike = {strike}")
        ax.set_xlabel("time stamps")
        ax.set_ylabel("close prices in Rs")
        ax.tick_params(axis='x', rotation=45)
        ax.legend()
 
        # ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M'))
        ax.xaxis.set_major_locator(mdates.AutoDateLocator())
        ax.xaxis.set_major_formatter(FuncFormatter(filter_ticks))
   
    for j in range(len(strikes_traded), len(axes)):
        figure.delaxes(axes[j])

    plt.tight_layout() 
    plt.show()

# %%
def filter_ticks(x, pos=None):
    dt = mdates.num2date(x)
    if dt.hour < 9 or (dt.hour == 15 and dt.minute > 29) or dt.hour > 15:
        return ''
    return dt.strftime('%Y-%m-%d %H:%M')

# %%
def plot_all_traded_options(df_options, df_ram, start, df_trades, filter_ticks):
    plot_options_and_trades(df_options, df_ram, 1, start, df_trades, filter_ticks)
    plot_options_and_trades(df_options, df_ram, 0, start, df_trades, filter_ticks)

# %%
plot_all_traded_options(df_options, df, '2023-12-05', df_trades, filter_ticks)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
class metrics:
    def __init__(self, trades, profits, fund_locked, risk_free_rate=12):
        self.fund_locked = fund_locked
        self.risk_free_rate = risk_free_rate
        self.trades = trades
        self.profits = pd.Series(profits)

    def number_of_trades(self):
        return self.trades.count().iloc[0]

    def net_profit(self):
        profits = self.profits
        return profits.sum()

    def net_turnover(self):
        prices = self.trades['Price']
        return prices.sum()
        
    def net_expenditure(self, transaction_costs = 11.5, slippage = 10):
        # 1% = 100 basis points => total_turnover * 0.01/100 * total_basis_points
        expenses = self.net_turnover() * (0.01/100) * (transaction_costs + slippage)
        return expenses

    def net_return(self):
        return 100*self.net_profit()/self.fund_locked

    def sharpe(self):
        std_profits = self.profits.std()
        std_returns = std_profits / self.fund_locked
        sharpe_ratio = self.net_return() - (self.risk_free_rate/ 12)
        sharpe_ratio /= 100
        sharpe_ratio /= std_returns
        return sharpe_ratio

    def max_drawdown(self):
        profits = self.profits
        increments = [(profits[i] - profits[i - 1]) for i in range(1, len(profits))]
        dd = 0
        max_dd = 0
        for inc in increments:
            dd += inc
            dd = min(0, dd)
            max_dd = min(dd, max_dd)
        return max_dd

# %%
# metrics = metrics(df_trades_test, profits_test, 100000, 12)
metrics = metrics(df_trades, profits, 10000000, 12)

# %%
number_of_trades = metrics.number_of_trades()
sharpe = metrics.sharpe()
net_profit = metrics.net_profit()
net_expenditure = metrics.net_expenditure()
net_return = metrics.net_return()
max_drawdown = metrics.max_drawdown()

print("number of trades:", number_of_trades)
print("sharpe:", sharpe)
print("net profit:", f"₹{net_profit/100}")
print("net expenditure (transaction costs + slippage):", f"₹{net_expenditure/100}")
print("net return:", f"{net_return}%")
print("max drawdown in PNL:", f"₹{abs(max_drawdown)/100}")
# Out:
# number of trades: 352
# sharpe: -51.56442524134144
# net profit: ₹-123.3
# net expenditure (transaction costs + slippage): ₹87.24936500000001
# net return: -0.1233%
# max drawdown in PNL: ₹221.0
