# %%
import pandas as pd
import Data_Processing as dp

# %%
dp.process_parse_options(pd.read_excel(r'.\SBIN_options.xlsx'))
# Out:
# ([strike               35000  40000  45000  46000  48000  48500  49000  49500  \
#   2022-12-30 09:15:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#   2022-12-30 09:16:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#   2022-12-30 09:17:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#   2022-12-30 09:18:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#   2022-12-30 09:19:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#   ...                    ...    ...    ...    ...    ...    ...    ...    ...
#   2023-01-25 15:25:00    5.0   15.0    5.0   40.0    5.0   10.0    5.0   25.0
#   2023-01-25 15:26:00    5.0   15.0    5.0   40.0    5.0   10.0    5.0   25.0
#   2023-01-25 15:27:00    5.0   15.0    5.0   40.0    5.0   10.0    5.0   25.0
#   2023-01-25 15:28:00    5.0   15.0    5.0   40.0    5.0   10.0    5.0   25.0
#   2023-01-25 15:29:00    5.0   15.0    5.0   40.0    5.0   10.0    5.0   25.0
#
# ...
